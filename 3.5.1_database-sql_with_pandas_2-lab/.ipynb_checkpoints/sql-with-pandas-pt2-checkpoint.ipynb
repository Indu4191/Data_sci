# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice SQL with Pandas pt. 2
#
# _Authors: Joseph Nelson (DC), Matt Brems (DC)_
#
# ---
#
# We've learned about relational databases and the language most use to query them, SQL.
#
# In this lab we are going to gain more practice converting information to a SQL DB, querying the data and then analyzing it with Python.

# %%
# Necessary Libraries
import pandas as pd
import sqlite3
from pandas.io import sql

# %% [markdown]
# ### 1.  Read in the EuroMart CSV Data
# - 'EuroMart-ListOfOrders.csv'
# - 'EuroMart-OrderBreakdown.csv'
# - 'EuroMart-SalesTargets.csv'

# %%
# Reading CSV to Dataframe
orders = pd.read_csv('/Users/Mahendra/desktop/GA/hw/3.5.1_database-sql_with_pandas_2-lab/datasets/csv/EuroMart-ListOfOrders.csv', encoding = 'utf-8')
OBD =  pd.read_csv('/Users/Mahendra/desktop/GA/hw/3.5.1_database-sql_with_pandas_2-lab/datasets/csv/EuroMart-OrderBreakdown.csv', encoding = 'utf-8')
sales_targets =  pd.read_csv('/Users/Mahendra/desktop/GA/hw/3.5.1_database-sql_with_pandas_2-lab/datasets/csv/EuroMart-SalesTargets.csv', encoding = 'utf-8')

# %% [markdown]
# ### 2 Rename columns to remove any spaces

# %%
orders.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
# A:
orders.columns
# Out:
# Index([u'Order_ID', u'Order_Date', u'Customer_Name', u'City', u'Country',
#        u'Region', u'Segment', u'Ship_Date', u'Ship_Mode', u'State'],
#       dtype='object')

# %%
OBD.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
OBD.columns
# Out:
# Index([u'Order_ID', u'Product_Name', u'Discount', u'Sales', u'Profit',
#        u'Quantity', u'Category', u'Sub-Category'],
#       dtype='object')

# %%
sales_targets.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
sales_targets.columns
# Out:
# Index([u'Month_of_Order_Date', u'Category', u'Target'], dtype='object')

# %% [markdown]
# ### 3. Remove dollar signs from sales and profit columns in the order breakdown dataframe.
#
# Convert the columns to float.

# %%
# A: 
OBD.head(5)
# Out:
#           Order_ID                           Product_Name  Discount    Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   $45.00
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  $854.00
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  $140.00
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   $27.00
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   $17.00
#
#     Profit  Quantity         Category Sub-Category
# 0  -$26.00         3  Office Supplies        Paper
# 1  $290.00         7        Furniture    Bookcases
# 2   $21.00         3  Office Supplies          Art
# 3  -$22.00         2  Office Supplies          Art
# 4   -$1.00         2  Office Supplies      Storage

# %%
OBD['Sales']=OBD['Sales'].str.replace(',','')
OBD['Sales']=OBD['Sales'].str.replace('$','')

# %%
OBD['Profit']=OBD['Profit'].str.replace(',','')
OBD['Profit']=OBD['Profit'].str.replace('$','')

# %%
OBD['Sales']=OBD['Sales'].astype(float)

# %%
OBD['Profit']=OBD['Profit'].astype(float)

# %%
OBD
# Out:
#              Order_ID                                       Product_Name  \
# 0     BN-2011-7407039                        Enermax Note Cards, Premium
# 1     AZ-2011-9050313                 Dania Corner Shelving, Traditional
# 2     AZ-2011-6674300              Binney & Smith Sketch Pad, Easy-Erase
# 3     BN-2011-2819714                         Boston Markers, Easy-Erase
# 4     BN-2011-2819714                        Eldon Folders, Single Width
# 5      AZ-2011-617423       Binney & Smith Pencil Sharpener, Water Color
# 6      AZ-2011-617423                        Sanford Canvas, Fluorescent
# 7     AZ-2011-2918397                      Bush Floating Shelf Set, Pine
# 8     AZ-2011-2918397                  Accos Thumb Tacks, Assorted Sizes
# 9     AZ-2011-2918397                          Smead Lockers, Industrial
# 10    BN-2011-3248724                       Ikea Classic Bookcase, Metal
# 11    BN-2011-3248724                    Binney & Smith Sketch Pad, Blue
# 12    AZ-2011-7053593              SAFCO Executive Leather Armchair, Red
# 13    AZ-2011-7053593                        Binney & Smith Canvas, Blue
# 14    AZ-2011-6439906          Bevis Training Table, with Bottom Storage
# 15    AZ-2011-4827146                         Boston Canvas, Fluorescent
# 16    AZ-2011-4827146                          Smead Trays, Single Width
# 17    AZ-2011-6439906           Novimex File Folder Labels, Alphabetical
# 18    AZ-2011-6712797                Ibico Hole Reinforcements, Recycled
# 19    AZ-2011-2222024                   Green Bar Note Cards, Multicolor
# 20    AZ-2011-9927716                           Hon Chairmat, Adjustable
# 21    AZ-2011-5702370               Ikea Stackable Bookrack, Traditional
# 22    AZ-2011-5702370                        Binney & Smith Canvas, Blue
# 23    AZ-2011-5702370                             Ibico Index Tab, Clear
# 24    AZ-2011-5702370                               Epson Printer, White
# 25    BN-2011-4913858          Wilson Jones Hole Reinforcements, Durable
# 26    BN-2011-4913858  Harbour Creations Legal Exhibit Labels, Laser ...
# 27    BN-2011-4913858            Green Bar Cards & Envelopes, Multicolor
# 28    BN-2011-4913858                                Smead Lockers, Blue
# 29    BN-2011-2807470                          Sanford Pens, Fluorescent
# ...               ...                                                ...
# 8017  AZ-2014-6752912            Motorola Signal Booster, with Caller ID
# 8018  BN-2014-4912801                              BIC Pens, Fluorescent
# 8019  BN-2014-4912801                         Sanford Highlighters, Blue
# 8020  BN-2014-3913645                               Stanley Canvas, Blue
# 8021  BN-2014-3913645                        Avery 3-Hole Punch, Economy
# 8022  AZ-2014-5388375                      Fellowes Shelving, Industrial
# 8023  BN-2014-3913645                                   Sharp Ink, Laser
# 8024  AZ-2014-5388375                              StarTech Phone, White
# 8025  AZ-2014-8026360                           Deflect-O Clock, Durable
# 8026  AZ-2014-8026360                             Epson Inkjet, Wireless
# 8027  AZ-2014-8026360                    Panasonic Card Printer, Durable
# 8028  AZ-2014-6630720              Kraft Mailers, with clear poly window
# 8029  BN-2014-8679573                          Cuisinart Blender, Silver
# 8030  AZ-2014-3870231                               Sanford Canvas, Blue
# 8031  AZ-2014-3870231                          Kleencut Ruler, Easy Grip
# 8032  AZ-2014-3870231                        Canon Fax and Copier, Laser
# 8033  AZ-2014-3870231                      Nokia Headset, with Caller ID
# 8034  AZ-2014-8007090                         Fellowes Box, Single Width
# 8035  AZ-2014-5047236                    Rubbermaid Door Stop, Erganomic
# 8036   AZ-2014-157670                   Office Star Chairmat, Adjustable
# 8037   AZ-2014-436448                               Acco Binder, Economy
# 8038  AZ-2014-1412225                    Fellowes Shelving, Single Width
# 8039  AZ-2014-4217323                       Fellowes Lockers, Wire Frame
# 8040  AZ-2014-8174835                          Kleencut Shears, Serrated
# 8041  AZ-2014-7604524                    Wilson Jones Index Tab, Economy
# 8042   AZ-2014-766953               Ikea Stackable Bookrack, Traditional
# 8043  BN-2014-4140795                  BIC Pencil Sharpener, Fluorescent
# 8044  BN-2014-4140795                      Avery Binder Covers, Recycled
# 8045  BN-2014-4140795                                StarTech Phone, Red
# 8046   AZ-2014-766953                          Motorola Audio Dock, VoIP
#
#       Discount   Sales  Profit  Quantity         Category Sub-Category
# 0         0.50    45.0   -26.0         3  Office Supplies        Paper
# 1         0.00   854.0   290.0         7        Furniture    Bookcases
# 2         0.00   140.0    21.0         3  Office Supplies          Art
# 3         0.50    27.0   -22.0         2  Office Supplies          Art
# 4         0.50    17.0    -1.0         2  Office Supplies      Storage
# 5         0.00    90.0    21.0         3  Office Supplies          Art
# 6         0.00   207.0    77.0         4  Office Supplies          Art
# 7         0.10   155.0    36.0         1        Furniture    Bookcases
# 8         0.00    33.0     2.0         3  Office Supplies    Fasteners
# 9         0.10   716.0   143.0         4  Office Supplies      Storage
# 10        0.60   987.0 -1012.0         6        Furniture    Bookcases
# 11        0.50   116.0   -56.0         5  Office Supplies          Art
# 12        0.00  1384.0    14.0         3        Furniture       Chairs
# 13        0.00   103.0    20.0         2  Office Supplies          Art
# 14        0.60   268.0  -342.0         2        Furniture       Tables
# 15        0.00    55.0    10.0         1  Office Supplies          Art
# 16        0.00    97.0    31.0         2  Office Supplies      Storage
# 17        0.00    40.0     6.0         5  Office Supplies       Labels
# 18        0.00    22.0     7.0         3  Office Supplies      Binders
# 19        0.50    34.0    -6.0         2  Office Supplies        Paper
# 20        0.00   290.0    70.0         5        Furniture       Chairs
# 21        0.10   552.0   165.0         5        Furniture    Bookcases
# 22        0.00   257.0    49.0         5  Office Supplies          Art
# 23        0.00    17.0     6.0         2  Office Supplies      Binders
# 24        0.00   522.0    21.0         2       Technology     Machines
# 25        0.50     9.0    -3.0         3  Office Supplies      Binders
# 26        0.50    22.0   -12.0         4  Office Supplies       Labels
# 27        0.50    50.0   -38.0         2  Office Supplies        Paper
# 28        0.50   198.0  -131.0         2  Office Supplies      Storage
# 29        0.50    31.0   -14.0         5  Office Supplies          Art
# ...        ...     ...     ...       ...              ...          ...
# 8017      0.15   487.0   143.0         4       Technology       Phones
# 8018      0.50    31.0   -11.0         4  Office Supplies          Art
# 8019      0.50     8.0    -6.0         1  Office Supplies          Art
# 8020      0.50    74.0   -51.0         3  Office Supplies          Art
# 8021      0.50    56.0     0.0         4  Office Supplies      Binders
# 8022      0.10    52.0    20.0         1  Office Supplies      Storage
# 8023      0.50   373.0  -254.0         6       Technology      Copiers
# 8024      0.10   131.0    45.0         2       Technology     Machines
# 8025      0.00   189.0    60.0         4        Furniture  Furnishings
# 8026      0.15   524.0   -25.0         2       Technology     Machines
# 8027      0.15   148.0     9.0         1       Technology     Machines
# 8028      0.10   148.0    23.0         4  Office Supplies    Envelopes
# 8029      0.50    68.0   -62.0         2  Office Supplies   Appliances
# 8030      0.00   152.0    44.0         3  Office Supplies          Art
# 8031      0.00    30.0     1.0         2  Office Supplies     Supplies
# 8032      0.00  1913.0   899.0        10       Technology      Copiers
# 8033      0.00   292.0    35.0         4       Technology       Phones
# 8034      0.00    39.0     2.0         2  Office Supplies      Storage
# 8035      0.00    85.0    13.0         2        Furniture  Furnishings
# 8036      0.00    68.0    27.0         1        Furniture       Chairs
# 8037      0.00    45.0     6.0         3  Office Supplies      Binders
# 8038      0.00   289.0    75.0         5  Office Supplies      Storage
# 8039      0.10   557.0   217.0         3  Office Supplies      Storage
# 8040      0.00   261.0    13.0         6  Office Supplies     Supplies
# 8041      0.00    32.0     8.0         5  Office Supplies      Binders
# 8042      0.00   245.0    91.0         2        Furniture    Bookcases
# 8043      0.50    30.0   -10.0         2  Office Supplies          Art
# 8044      0.50    23.0    -6.0         4  Office Supplies      Binders
# 8045      0.50   108.0   -19.0         3       Technology     Machines
# 8046      0.00   867.0   251.0         5       Technology       Phones
#
# [8047 rows x 8 columns]

# %% [markdown]
# ### 4. Create a SQL Database called 'EuroMart' and save the three dataframes as SQL tables.

# %%
# Establishing Local DB connection
db_connection = sqlite3.connect('/Users/Mahendra/desktop/GA/hw/3.5.1_database-sql_with_pandas_2-lab/datasets/sql/EuroMart.db.sqlite')

# %%
orders.to_sql('orders',con=db_connection, if_exists='replace',index=False)
OBD.to_sql(name = 'order_breakdown', con = db_connection, if_exists = 'replace', index = False)
sales_targets.to_sql(name = 'sales_targets', con = db_connection, if_exists = 'replace', index = False)

# %%
def Q(query,db=db_connection):
    return sql.read_sql(query,db)

# %% [markdown]
# ### 5. How many orders has each Customer placed?

# %%
# A:
query= '''
select * from orders 
limit 5
'''
Q(query,db=db_connection)
# Out:
#           Order_ID Order_Date     Customer_Name        City         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423   1/5/2011      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship_Date     Ship_Mode                 State
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4  Central  Home Office  1/7/2011      Priority  Auvergne-Rhône-Alpes

# %%
q1='''
select "Customer_Name",count(*)
from
orders
group by "Customer_Name"

'''
Q(q1,db=db_connection)
# Out:
#             Customer_Name  count(*)
# 0           Aaron Bootman        11
# 1        Aaron Cunningham         8
# 2             Aaron Davey         4
# 3         Aaron Macrossan         1
# 4             Abbie Perry         4
# 5             Abby Colebe         3
# 6                Abby Mei         6
# 7           Abby Muramats         5
# 8        Abigail Humffray         5
# 9              Ada Dalton         4
# 10           Adam Bentley         3
# 11             Adam Gibbs         4
# 12             Adam Harte         8
# 13           Adam Peacock         4
# 14           Adam Walpole         7
# 15          Aidan Hayward         7
# 16             Aidan Rowe         8
# 17            Alana Tyson         4
# 18            Alana Zahel         7
# 19       Alannah Callaway         5
# 20      Alannah Langridge         9
# 21         Alex Greenwood         7
# 22      Alexander Bennett         6
# 23         Alexander Bond         4
# 24    Alexandra Macdonald        10
# 25      Alexandra Mahmood         1
# 26       Alexandra Portus         5
# 27   Alexandra Whitehouse         7
# 28            Alexis Code         8
# 29      Alexis O'Flaherty         3
# ..                    ...       ...
# 762        Tyson Jonathan         9
# 763          Vaughn Gibbs         5
# 764           Victor Kron         5
# 765         Victoria Bell         3
# 766        Victoria Burke         4
# 767          Viola Watson         5
# 768        Walter Aguilar         7
# 769          Walter Coley         6
# 770         Wanda Wingert         3
# 771          Will Poynton         7
# 772        William Horton         5
# 773         William Jolly         5
# 774        William Martin         3
# 775      William Reichert         4
# 776    William Somerville         5
# 777           Winnie Moss         6
# 778        Wynona Janelle         4
# 779        Xavier Burford         6
# 780     Xavier Martindale         3
# 781          Xavier Synan         5
# 782        Yasmin Bradley         3
# 783        Yasmin Higgins         2
# 784        Zachary Disher         7
# 785        Zachary Warner         9
# 786         Zara Jennings         2
# 787            Zara Loton         3
# 788            Zara Money         5
# 789           Zoe Lanigan         4
# 790             Zoe Lowin         4
# 791            Zona Meyer         8
#
# [792 rows x 2 columns]

# %% [markdown]
# > *If you're doubting your output check using Pandas*

# %% [markdown]
# ### 6. Create a Query to return a table of only geographic features from the List of Orders Table.

# %%
# A:
q6='''
select "City","State","Country","Region"
from orders
'''
Q(q6,db=db_connection)
# Out:
#                      City                               State         Country  \
# 0               Stockholm                           Stockholm          Sweden
# 1               Southport                             England  United Kingdom
# 2                 Valence                Auvergne-Rhône-Alpes          France
# 3              Birmingham                             England  United Kingdom
# 4              Echirolles                Auvergne-Rhône-Alpes          France
# 5        La Seyne-sur-Mer          Provence-Alpes-Côte d'Azur          France
# 6                Toulouse  Languedoc-Roussillon-Midi-Pyrénées          France
# 7                   Genoa                             Liguria           Italy
# 8                  Vienna                              Vienna         Austria
# 9                  Murcia                              Murcia           Spain
# 10                 Woking                             England  United Kingdom
# 11                  Lohne                        Lower Saxony         Germany
# 12              Leicester                             England  United Kingdom
# 13              Sheffield                             England  United Kingdom
# 14              Dordrecht                       South Holland     Netherlands
# 15             Gothenburg                     Västra Götaland          Sweden
# 16                 Vienna                              Vienna         Austria
# 17                 Langen                        Lower Saxony         Germany
# 18             Copenhagen                         Hovedstaden         Denmark
# 19                 Gandia                          Valenciana           Spain
# 20                Esbjerg                       South Denmark         Denmark
# 21     Sesto San Giovanni                            Lombardy           Italy
# 22                Trapani                              Sicily           Italy
# 23     Villiers-sur-Marne                       Ile-de-France          France
# 24              Bielefeld              North Rhine-Westphalia         Germany
# 25                 Leuven                     Flemish Brabant         Belgium
# 26                  Prato                             Tuscany           Italy
# 27                   Gela                              Sicily           Italy
# 28                Bologna                      Emilia-Romagna           Italy
# 29                 Menden              North Rhine-Westphalia         Germany
# ...                   ...                                 ...             ...
# 4087                 Linz                       Upper Austria         Austria
# 4088               Lisbon                              Lisboa        Portugal
# 4089              Ferrara                      Emilia-Romagna           Italy
# 4090             Schwerin              Mecklenburg-Vorpommern         Germany
# 4091            Stockholm                           Stockholm          Sweden
# 4092               Harrow                             England  United Kingdom
# 4093                Milan                            Lombardy           Italy
# 4094            Stockholm                           Stockholm          Sweden
# 4095            The Hague                       South Holland     Netherlands
# 4096        Wolverhampton                             England  United Kingdom
# 4097               London                             England  United Kingdom
# 4098  Champigny-sur-Marne                       Ile-de-France          France
# 4099             Pamplona                             Navarra           Spain
# 4100              Oyonnax                Auvergne-Rhône-Alpes          France
# 4101            Sarcelles                       Ile-de-France          France
# 4102              Haarlem                       North Holland     Netherlands
# 4103            Stockholm                           Stockholm          Sweden
# 4104               Dublin                              Dublin         Ireland
# 4105             Plymouth                             England  United Kingdom
# 4106               Munich                             Bavaria         Germany
# 4107            Edinburgh                            Scotland  United Kingdom
# 4108               Naples                            Campania           Italy
# 4109                Basel                         Basel-Stadt     Switzerland
# 4110            The Hague                       South Holland     Netherlands
# 4111                 Caen                            Normandy          France
# 4112            Bielefeld              North Rhine-Westphalia         Germany
# 4113           Maidenhead                             England  United Kingdom
# 4114            Worcester                             England  United Kingdom
# 4115              Hamburg                             Hamburg         Germany
# 4116            Eindhoven                       North Brabant     Netherlands
#
#        Region
# 0       North
# 1       North
# 2     Central
# 3       North
# 4     Central
# 5     Central
# 6     Central
# 7       South
# 8     Central
# 9       South
# 10      North
# 11    Central
# 12      North
# 13      North
# 14    Central
# 15      North
# 16    Central
# 17    Central
# 18      North
# 19      South
# 20      North
# 21      South
# 22      South
# 23    Central
# 24    Central
# 25    Central
# 26      South
# 27      South
# 28      South
# 29    Central
# ...       ...
# 4087  Central
# 4088    South
# 4089    South
# 4090  Central
# 4091    North
# 4092    North
# 4093    South
# 4094    North
# 4095  Central
# 4096    North
# 4097    North
# 4098  Central
# 4099    South
# 4100  Central
# 4101  Central
# 4102  Central
# 4103    North
# 4104    North
# 4105    North
# 4106  Central
# 4107    North
# 4108    South
# 4109  Central
# 4110  Central
# 4111  Central
# 4112  Central
# 4113    North
# 4114    North
# 4115  Central
# 4116  Central
#
# [4117 rows x 4 columns]

# %% [markdown]
# ### 7. Create a Query to return a table with all of the orders that had a negative profit from the Order Breakdown Table.

# %%
# A:
q7='''
select *
from order_breakdown
where "Profit" <0
'''
Q(q7,db=db_connection)
# Out:
#              Order_ID                                       Product_Name  \
# 0     BN-2011-7407039                        Enermax Note Cards, Premium
# 1     BN-2011-2819714                         Boston Markers, Easy-Erase
# 2     BN-2011-2819714                        Eldon Folders, Single Width
# 3     BN-2011-3248724                       Ikea Classic Bookcase, Metal
# 4     BN-2011-3248724                    Binney & Smith Sketch Pad, Blue
# 5     AZ-2011-6439906          Bevis Training Table, with Bottom Storage
# 6     AZ-2011-2222024                   Green Bar Note Cards, Multicolor
# 7     BN-2011-4913858          Wilson Jones Hole Reinforcements, Durable
# 8     BN-2011-4913858  Harbour Creations Legal Exhibit Labels, Laser ...
# 9     BN-2011-4913858            Green Bar Cards & Envelopes, Multicolor
# 10    BN-2011-4913858                                Smead Lockers, Blue
# 11    BN-2011-2807470                          Sanford Pens, Fluorescent
# 12    BN-2011-3770060      Hon Shipping Labels, Laser Printer Compatible
# 13    AZ-2011-1816950                      Acco Binding Machine, Economy
# 14    BN-2011-7883641         Harbour Creations Swivel Stool, Set of Two
# 15    BN-2011-7883641                 Office Star Bag Chairs, Set of Two
# 16    BN-2011-6722454                        Hewlett Wireless Fax, Laser
# 17     BN-2011-486854                       Rogers Folders, Single Width
# 18     AZ-2011-838467                          Xerox Note Cards, Premium
# 19     AZ-2011-838467                  Motorola Signal Booster, Cordless
# 20    BN-2011-2468159                     SanDisk Memo Slips, Multicolor
# 21    BN-2011-2468159                 Logitech Numeric Keypad, Erganomic
# 22    BN-2011-2468159                        Hewlett Copy Machine, Color
# 23    BN-2011-2468159                                Konica Phone, White
# 24    BN-2011-7087921                Boston Pencil Sharpener, Easy-Erase
# 25    AZ-2011-5195846               GlobeWeis Manila Envelope, Set of 50
# 26    AZ-2011-5195846                           Rogers Trays, Wire Frame
# 27    AZ-2011-9107304                          Smead Folders, Wire Frame
# 28    BN-2011-3032749                         Avery Binder Covers, Clear
# 29    BN-2011-3032749                        Tenex File Cart, Industrial
# ...               ...                                                ...
# 1704  BN-2014-1926985                     Advantus Light Bulb, Erganomic
# 1705  AZ-2014-9082134                                Apple Headset, VoIP
# 1706  BN-2014-1926985                           Panasonic Phone, Durable
# 1707  AZ-2014-1328396                        Hoover Refrigerator, Silver
# 1708  AZ-2014-7188993                                    Smead Box, Blue
# 1709  BN-2014-7634157               Smead File Folder Labels, Adjustable
# 1710  BN-2014-5013417         Chromcraft Wood Table, with Bottom Storage
# 1711  BN-2014-2971842                   Wilson Jones Index Tab, Recycled
# 1712  BN-2014-2971842                                      HP Ink, Laser
# 1713  AZ-2014-2210711                      HP Fax and Copier, High-Speed
# 1714  BN-2014-5182753                      Advantus Photo Frame, Durable
# 1715  BN-2014-5182753                               BIC Sketch Pad, Blue
# 1716  BN-2014-5182753                   Stockwell Thumb Tacks, Bulk Pack
# 1717  AZ-2014-7108585                        Okidata Calculator, Durable
# 1718  BN-2014-5182753                      Belkin Flash Drive, Bluetooth
# 1719  BN-2014-9956954                Harbour Creations Bag Chairs, Black
# 1720  BN-2014-2616164                     KitchenAid Refrigerator, Black
# 1721  BN-2014-6319094  Harbour Creations Round Labels, Laser Printer ...
# 1722  BN-2014-6319094                       Fellowes Lockers, Wire Frame
# 1723  BN-2014-6319094                        Panasonic Card Printer, Red
# 1724  BN-2014-5301206                       Novimex Rocking Chair, Black
# 1725  BN-2014-4912801                              BIC Pens, Fluorescent
# 1726  BN-2014-4912801                         Sanford Highlighters, Blue
# 1727  BN-2014-3913645                               Stanley Canvas, Blue
# 1728  BN-2014-3913645                                   Sharp Ink, Laser
# 1729  AZ-2014-8026360                             Epson Inkjet, Wireless
# 1730  BN-2014-8679573                          Cuisinart Blender, Silver
# 1731  BN-2014-4140795                  BIC Pencil Sharpener, Fluorescent
# 1732  BN-2014-4140795                      Avery Binder Covers, Recycled
# 1733  BN-2014-4140795                                StarTech Phone, Red
#
#       Discount   Sales  Profit  Quantity         Category Sub-Category
# 0         0.50    45.0   -26.0         3  Office Supplies        Paper
# 1         0.50    27.0   -22.0         2  Office Supplies          Art
# 2         0.50    17.0    -1.0         2  Office Supplies      Storage
# 3         0.60   987.0 -1012.0         6        Furniture    Bookcases
# 4         0.50   116.0   -56.0         5  Office Supplies          Art
# 5         0.60   268.0  -342.0         2        Furniture       Tables
# 6         0.50    34.0    -6.0         2  Office Supplies        Paper
# 7         0.50     9.0    -3.0         3  Office Supplies      Binders
# 8         0.50    22.0   -12.0         4  Office Supplies       Labels
# 9         0.50    50.0   -38.0         2  Office Supplies        Paper
# 10        0.50   198.0  -131.0         2  Office Supplies      Storage
# 11        0.50    31.0   -14.0         5  Office Supplies          Art
# 12        0.50    17.0    -8.0         3  Office Supplies       Labels
# 13        0.50    26.0   -11.0         1  Office Supplies      Binders
# 14        0.60    73.0   -57.0         1        Furniture       Chairs
# 15        0.60    69.0   -95.0         3        Furniture       Chairs
# 16        0.50   570.0  -217.0         3       Technology      Copiers
# 17        0.10    28.0    -1.0         1  Office Supplies      Storage
# 18        0.50    13.0    -8.0         1  Office Supplies        Paper
# 19        0.50   584.0   -59.0         8       Technology       Phones
# 20        0.50    46.0   -41.0         5  Office Supplies        Paper
# 21        0.50    44.0    -8.0         2       Technology  Accessories
# 22        0.65   550.0  -236.0         6       Technology      Copiers
# 23        0.65    89.0   -76.0         3       Technology     Machines
# 24        0.50    91.0   -62.0         6  Office Supplies          Art
# 25        0.50    55.0   -19.0         4  Office Supplies    Envelopes
# 26        0.50    91.0    -2.0         3  Office Supplies      Storage
# 27        0.10    60.0    -3.0         4  Office Supplies      Storage
# 28        0.50    26.0   -14.0         5  Office Supplies      Binders
# 29        0.60   215.0  -220.0         4  Office Supplies      Storage
# ...        ...     ...     ...       ...              ...          ...
# 1704      0.60    67.0   -86.0         9        Furniture  Furnishings
# 1705      0.15    62.0    -1.0         1       Technology       Phones
# 1706      0.50    42.0    -3.0         1       Technology     Machines
# 1707      0.50   527.0  -190.0         2  Office Supplies   Appliances
# 1708      0.10    10.0    -1.0         1  Office Supplies      Storage
# 1709      0.50    24.0   -21.0         7  Office Supplies       Labels
# 1710      0.35   941.0  -203.0         3        Furniture       Tables
# 1711      0.50    20.0    -9.0         6  Office Supplies      Binders
# 1712      0.50   322.0  -193.0         5       Technology      Copiers
# 1713      0.65   120.0   -89.0         2       Technology      Copiers
# 1714      0.60    20.0   -22.0         1        Furniture  Furnishings
# 1715      0.50    49.0   -31.0         2  Office Supplies          Art
# 1716      0.50    34.0   -13.0         5  Office Supplies    Fasteners
# 1717      0.15   134.0   -13.0         3       Technology     Machines
# 1718      0.50    21.0    -5.0         1       Technology  Accessories
# 1719      0.60    24.0   -30.0         1        Furniture       Chairs
# 1720      0.50  1582.0  -443.0         6  Office Supplies   Appliances
# 1721      0.50    17.0   -12.0         5  Office Supplies       Labels
# 1722      0.50   929.0   -93.0         9  Office Supplies      Storage
# 1723      0.50   342.0  -103.0         4       Technology     Machines
# 1724      0.50   516.0  -392.0         8        Furniture       Chairs
# 1725      0.50    31.0   -11.0         4  Office Supplies          Art
# 1726      0.50     8.0    -6.0         1  Office Supplies          Art
# 1727      0.50    74.0   -51.0         3  Office Supplies          Art
# 1728      0.50   373.0  -254.0         6       Technology      Copiers
# 1729      0.15   524.0   -25.0         2       Technology     Machines
# 1730      0.50    68.0   -62.0         2  Office Supplies   Appliances
# 1731      0.50    30.0   -10.0         2  Office Supplies          Art
# 1732      0.50    23.0    -6.0         4  Office Supplies      Binders
# 1733      0.50   108.0   -19.0         3       Technology     Machines
#
# [1734 rows x 8 columns]

# %% [markdown]
# ### 8. Construct a query to return a table with the Customer Name and Product Name.
#
# > **Note:** This will require a join!

# %%
# A:
q8='''
select o."Order_ID", o."Customer_Name", ob."Product_Name"
from orders o,order_breakdown ob
group by o."Order_ID"
'''
Q(q8,db=db_connection)

# %% [markdown]
# ### 9.  How many orders for "Office Supplies" (Category) has Sweden made?
#
# > **Note:** from this point on you'll probably be combining SQL and Pandas, in that you would use SQL querys to gather the relevant information and use Pandas to analyze it.

# %%
# A:

# %% [markdown]
# ### 10. What was the total sales for products that have been discounted?

# %%
# A:

# %% [markdown]
# ### 11. What is the total quantity of objects sold for each country?

# %%
# A:

# %% [markdown]
# ### 12. In what Countries are profits lowest? (Report lowest 5-10)

# %%
# A:

# %% [markdown]
# ### 13. What Counties have the best and worst Sales to Profit Ratios?
# (Total Sales divided by Total Profits.)
# Essentially this is saying for every dollar of product sold, how much is profit.

# %%
# A:

# %% [markdown]
# ### 14. What Shipping method is most common for 'Bookcases' (Sub Category)

# %%
# A:

# %% [markdown]
# ### 15 .What city in the Orders table generated the highest net sales?  (List all the cities and countries in descending order by net sales.)

# %%
# A:

# %% [markdown]
# ### 16. [BONUS] Create a Column called 'Shipping Delay' on the 'orders' table, which is the difference in days between 'Order Date' and 'Ship Date'.

# %%
# A:

# %%
# A:

# %% [markdown]
# ### 17. [BONUS] Update your Orders table in your Sqlite DB to include the 'Shipping Delay' feature.

# %%
# A:

# %% [markdown]
# ### 18. [BONUS] Which Product Category has the highest average 'Shipping Delay'

# %%
# A:

# %% [markdown]
# ## Challenge problem: In what months and Categories were Sales Targets Exceeded?
#
# ---
#
# **This problem is more challenging.**
#
# Try it out if you want to test your skills! Like the bonus questions, it is not expected that you complete it.
#
# This may require a considerable amount of data processing.

# %%
# A:
