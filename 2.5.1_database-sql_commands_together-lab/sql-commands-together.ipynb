# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # SQL Together Lab
#
# _Authors: Dave Yerrington (SF)_
#
# ---
#
# > **This is a hybrid lecture/lab. Each exercise is intended to be completed by a student in front of the class.**
#
#
# ### Learning Objectives
# *After this lesson, you will be able to:*
# - Sort results by a column using `ORDER BY`
# - Simplify our syntax using aliases (`AS`)
# - Match patterns using `LIKE`
# - Select distinct items using `DISTINCT`
# - Aggregate values using `GROUP BY`
# - Filter on aggregations using `HAVING`
# - Apply `IF/THEN` logic using `CASE`
# - Use `EXTRACT` to get date parts

# %% [markdown]
# ### Lesson Guide
# - [Install psycopg2](#install-psycopg2)
# - [Connect to remote database](#connect-to-remote)
# - [Some notes on syntax](#syntax-notes)
# - [ORDER BY](#order-by)
# - [Alias AS](#alias-as)
# - [LIKE](#like-operator)
# - [DISTINCT](#distinct)
# - [LIMIT](#limit)
# - [GROUP BY](#group-by)
# - [HAVING](#having)
# - [CASE statements](#case)
# - [Working with dates](#dates)
# - [Additional exercises](#additional-exercises)
# - [Conclusion](#conclusion)
# - [Additional resources](#additional-resources)

# %% [markdown]
# <a id='install-psycopg2'></a>
# ## Install `psycopg2`
#
# ---
#
# Either:
#
# `> conda install psycopg2`
#
# Or:
#
# `> pip install psycopg2`

# %% [markdown]
# <a id='connect-to-remote'></a>
# ## Connect to the remote database
#
# ---

# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

conn_str = "host='dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com' dbname='northwind' user='dsi_student' password='gastudents'"
conn = psycopg2.connect(conn_str)

# %% [markdown]
# <a id='syntax-notes'></a>
#
# ## A couple of notes on syntax
#
# ---
#
# The [Northwind Database Schema](https://northwinddatabase.codeplex.com/) will come in handy for writing your solutions to the problems below.
#
# 1. You want to wrap column names in double quotes **"column_name"**
# 2. You can comment out a line by including a double dash in front **--**
# 3. You want to wrap a string in single quotes **'string'**
#
# ```*.sql
# SELECT "ProductID" as "PID"
# FROM Products
# WHERE "ProductName" like '%a'
# --AND
# ```

# %% [markdown]
# <a id='order-by'></a>
#
# ## `ORDER BY`
#
# ---
#
# The `ORDER BY` keyword is used to sort the result-set by one or more columns. It sorts the records in ascending order by default. To sort the records in a descending order, you can use the `DESC` keyword.
#
# ### SQL `ORDER BY` syntax
#
# ```*.sql
# SELECT _column_name_,_ column_name_
# FROM _table_name_
# ORDER BY _column_name _ASC|DESC,_ column_name_ ASC|DESC;
# ```

# %% [markdown]
# ### Exercise 1:
#
# Select the `ProductID`, `ProductName`, `SupplierID`, and `UnitPrice` for all `Products` with a `UnitPrice > 25` ordered by `SupplierID` descending and then `UnitPrice` ascending.

# %%
SQL_STRING='''
select "ProductID" "PID", "ProductName" "PD",
"SupplierID" "SID", "UnitPrice" "UP"
from Products as p
where p."UnitPrice" >25
order by "SID" DESC , "UP" ASC

'''
df=pd.read_sql(SQL_STRING,con=conn)
df
# Out:
#     PID                               PD  SID      UP
# 0    61                   Sirop d'érable   29   28.50
# 1    62                   Tarte au sucre   29   49.30
# 2    60                Camembert Pierrot   28   34.00
# 3    59             Raclette Courdavault   28   55.00
# 4    56           Gnocchi di nonna Alice   26   38.00
# 5    53                    Perth Pasties   24   32.80
# 6    51            Manjimup Dried Apples   24   53.00
# 7    43                      Ipoh Coffee   20   46.00
# 8    38                    Côte de Blaye   18  263.50
# 9    37                       Gravad lax   17   26.00
# 10   69                 Gudbrandsdalsost   15   36.00
# 11   32               Mascarpone Fabioli   14   32.00
# 12   72           Mozzarella di Giovanni   14   34.80
# 13   30            Nord-Ost Matjeshering   13   25.89
# 14   64        Wimmers gute Semmelknödel   12   33.25
# 15   28                Rössle Sauerkraut   12   45.60
# 16   29          Thüringer Rostbratwurst   12  123.79
# 17   26              Gumbär Gummibärchen   11   31.23
# 18   27               Schoggi Schokolade   11   43.90
# 19   20           Sir Rodney's Marmalade    8   81.00
# 20   17                     Alice Mutton    7   39.00
# 21   63                     Vegie-spread    7   43.90
# 22   18                 Carnarvon Tigers    7   62.50
# 23   12        Queso Manchego La Pastora    5   38.00
# 24   10                            Ikura    4   31.00
# 25    9                  Mishi Kobe Niku    4   97.00
# 26    7  Uncle Bob's Organic Dried Pears    3   30.00
# 27    8       Northwoods Cranberry Sauce    3   40.00

# %% [markdown]
# <a id='alias-as'></a>
# ## Alias `AS`
#
# ---
#
# SQL aliases are used to give a database table, or a column in a table, a temporary name. Aliases are often created to make column names more readable and to make queries more concise.
#
# ### SQL alias syntax for columns
#
# ```*.sql
# SELECT _column_name_ AS _alias_name_
# FROM _table_name;_
# ```
#
# ### SQL alias syntax for tables
#
# ```*.sql
# SELECT _column_name(s)_
# FROM _table_name _AS _alias_name;_
# ```

# %% [markdown]
# ### Exercise 2
#
# Select `SupplierID` and `CompanyName` from the `Suppliers` table aliasing these columns as `Supplier No.` and `Company Name` respectively. Also alias the table as `S`. Order By `CompanyName` ascending.

# %%
# A:
SQL_QUERY='''
select "SupplierID" as "Supplier No.",
"CompanyName" as "Company Name"
from Suppliers  S
order by S."CompanyName" ASC
'''
df=pd.read_sql(SQL_QUERY,con=conn)
df
# Out:
#     Supplier No.                            Company Name
# 0             18              Aux joyeux ecclésiastiques
# 1             16                       Bigfoot Breweries
# 2              5      Cooperativa de Quesos 'Las Cabras'
# 3             27                      Escargots Nouveaux
# 4              1                          Exotic Liquids
# 5             29                        Forêts d'érables
# 6             14                 Formaggi Fortini s.r.l.
# 7             28                            Gai pâturage
# 8             24                             G'day, Mate
# 9              3               Grandma Kelly's Homestead
# 10            11             Heli Süßwaren GmbH & Co. KG
# 11            23                               Karkki Oy
# 12            20                            Leka Trading
# 13            21                              Lyngbysild
# 14            25                               Ma Maison
# 15             6                                Mayumi's
# 16            19             New England Seafood Cannery
# 17             2              New Orleans Cajun Delights
# 18            13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 19            15                         Norske Meierier
# 20            26                    Pasta Buttini s.r.l.
# 21             7                           Pavlova, Ltd.
# 22             9                        PB Knäckebröd AB
# 23            12       Plutzer Lebensmittelgroßmärkte AG
# 24            10               Refrescos Americanas LTDA
# 25             8                Specialty Biscuits, Ltd.
# 26            17                       Svensk Sjöföda AB
# 27             4                           Tokyo Traders
# 28            22                     Zaanse Snoepfabriek

# %% [markdown]
# **Aliases can be useful when:**
#
# - More than one table is involved in a query
# - Functions are used in the query
# - Column names are long or not very readable
# - Two or more columns are combined together

# %% [markdown]
# <a id='like-operator'></a>
# ## SQL `LIKE` operator
#
# ---
#
# The `LIKE` operator is used in a `WHERE` clause to search for a specified pattern in a column.
#
#
# ### SQL `LIKE` syntax
#
# ```*.sql
#
# SELECT _column_name(s)_
# FROM _table_name_
# WHERE _column_name_ LIKE _pattern_;
#
# ```
#
# > **Tip**: The `"%"` sign is used to define wildcards (missing letters) both before and after the pattern. Also notice that PostgreSQL is case sensitive.

# %% [markdown]
# ### Exercise 3
#
# Select all products from the product table with a `ProductName` that contain "ch" in descending order. Alias this column as `Ch Products`.

# %%
def Q(SQL_Query,con=conn):
    return(pd.read_sql(SQL_Query,con=conn))

# %%
SQL_Query3='''
select "ProductName" as "Ch Products"
from products p
where "ProductName" like '%ch%'
order by "ProductName" DESC;
'''
Q(SQL_Query3,con=conn)
# Out:
#                  Ch Products
# 0         Schoggi Schokolade
# 1              Sasquatch Ale
# 2  Queso Manchego La Pastora
# 3               Pâté chinois
# 4        Gumbär Gummibärchen
# 5     Gnocchi di nonna Alice

# %% [markdown]
# ### Exercise 4
#
# Select all products from the `Suppliers` table with a `City` that starts with "S" in ascending order. Alias this column as `S Cities`.

# %%
# A:
SQL_Q4='''
select "City" as " S Cities"
from Suppliers 
where "City" like 'S%'
order by "City" ASC
'''
Q(SQL_Q4,con=conn)
# Out:
#         S Cities
# 0        Salerno
# 1       Sandvika
# 2      Sao Paulo
# 3      Singapore
# 4  Ste-Hyacinthe
# 5      Stockholm
# 6         Sydney

# %% [markdown]
# <a id='distinct'></a>
# ## The `DISTINCT` operator
#
# ---
#
# The `SELECT DISTINCT` statement is used to return only distinct (unique) values. In a table, a column may contain many duplicate values; sometimes you only want to list the unique ones.
#
# ### `SELECT DISTINCT` syntax
#
# ```*.sql
#
# SELECT DISTINCT _column_name_,_column_name_
# FROM _table_name_;
#
# ```

# %% [markdown]
# ### Exercise 5
#
# `SELECT DISTINCT` `SupplierID`, `ProductName` and `UnitPrice` from the `Products` table ordering by `UnitPrice` ascending (the cheapest product for each supplier).

# %%
Query5='''
select DISTINCT "SupplierID",
"ProductName","UnitPrice"
from Products p
order by p."UnitPrice" ASC
'''
Q(Query5,con=conn)
# Out:
#     SupplierID                      ProductName  UnitPrice
# 0           15                          Geitost       2.50
# 1           10               Guaraná Fantástica       4.50
# 2            6                            Konbu       6.00
# 3           24                         Filo Mix       7.00
# 4           25                        Tourtière       7.45
# 5           12             Rhönbräu Klosterbier       7.75
# 6            9                         Tunnbröd       9.00
# 7            8       Teatime Chocolate Biscuits       9.20
# 8           21                      Rogede sild       9.50
# 9           22                    Zaanse koeken       9.50
# 10          19  Jack's New England Clam Chowder       9.65
# 11           1                    Aniseed Syrup      10.00
# 12           4                    Longlife Tofu      10.00
# 13           8              Sir Rodney's Scones      10.00
# 14          21                        Spegesild      12.00
# 15           8              Scottish Longbreads      12.50
# 16          14                Gorgonzola Telino      12.50
# 17          22                        Chocolade      12.75
# 18           6                     Genen Shouyu      13.00
# 19          12  Original Frankfurter grüne Soße      13.00
# 20          27           Escargots de Bourgogne      13.25
# 21          11          NuNuCa Nuß-Nougat-Creme      14.00
# 22          16        Laughing Lumberjack Lager      14.00
# 23          16                    Sasquatch Ale      14.00
# 24          20    Singaporean Hokkien Fried Mee      14.00
# 25           7                    Outback Lager      15.00
# 26          17                       Röd Kaviar      15.00
# 27          23                 Valkoinen suklaa      16.25
# 28           2        Louisiana Hot Spiced Okra      17.00
# 29           7                          Pavlova      17.45
# ..         ...                              ...        ...
# 47          25                     Pâté chinois      24.00
# 48           3     Grandma's Boysenberry Spread      25.00
# 49          13            Nord-Ost Matjeshering      25.89
# 50          17                       Gravad lax      26.00
# 51          29                   Sirop d'érable      28.50
# 52           3  Uncle Bob's Organic Dried Pears      30.00
# 53           4                            Ikura      31.00
# 54          11              Gumbär Gummibärchen      31.23
# 55          14               Mascarpone Fabioli      32.00
# 56          24                    Perth Pasties      32.80
# 57          12        Wimmers gute Semmelknödel      33.25
# 58          28                Camembert Pierrot      34.00
# 59          14           Mozzarella di Giovanni      34.80
# 60          15                 Gudbrandsdalsost      36.00
# 61           5        Queso Manchego La Pastora      38.00
# 62          26           Gnocchi di nonna Alice      38.00
# 63           7                     Alice Mutton      39.00
# 64           3       Northwoods Cranberry Sauce      40.00
# 65           7                     Vegie-spread      43.90
# 66          11               Schoggi Schokolade      43.90
# 67          12                Rössle Sauerkraut      45.60
# 68          20                      Ipoh Coffee      46.00
# 69          29                   Tarte au sucre      49.30
# 70          24            Manjimup Dried Apples      53.00
# 71          28             Raclette Courdavault      55.00
# 72           7                 Carnarvon Tigers      62.50
# 73           8           Sir Rodney's Marmalade      81.00
# 74           4                  Mishi Kobe Niku      97.00
# 75          12          Thüringer Rostbratwurst     123.79
# 76          18                    Côte de Blaye     263.50
#
# [77 rows x 3 columns]

# %% [markdown]
# <a id='limit'></a>
#
# ## The `LIMIT` operator
#
# ---
#
# Sometimes we may want to only retrieve a fixed number of records from the database. This is where the `LIMIT` operator comes in.
#
#
# ### `LIMIT` syntax
#
# ```*.sql
#
# SELECT _column_name_,_column_name_
# FROM _table_name_
# LIMIT _number_of_records;
#
# ```

# %% [markdown]
# ### Exercise 6
#
# Return the 5 highest priced Products that contain an **a** in the product name in ascending order. Alias the column as Top 5 A Products.

# %%
# A:
Query6='''
select "ProductName","UnitPrice"
from Products p
where p."ProductName" like '%a%'
order by p."ProductName" ASC
LIMIT 5
'''
Q(Query6,con=conn)
# Out:
#          ProductName  UnitPrice
# 0   Boston Crab Meat       18.4
# 1  Camembert Pierrot       34.0
# 2   Carnarvon Tigers       62.5
# 3               Chai       18.0
# 4              Chang       19.0

# %% [markdown]
# <a id='group-by'></a>
# ## `GROUP BY` Operator
#
# ---
#
# A table may contain several records that have a common key.
#
# The GROUP BY statement is used in conjunction with the aggregate functions to group the result-set by one or more columns. For example, we may want to know the total number of items purchased within each order.
#
# ### `GROUP BY` syntax
#
# ```*.sql
# SELECT column_name, aggregate_function(column_name)
# FROM table_name
# WHERE column_name operator value
# GROUP BY column_name;
# ```
#
# The aggregate functions that you can use with `GROUP BY` are:
# - **`COUNT`**
# - **`MIN`**
# - **`MAX`**
# - **`SUM`**
# - **`AVG`**

# %% [markdown]
# ### Exercise 7
#
# From the `order_details` table show the count of orders per OrderID and the SUM of the revenue (`UnitPrice * Quantity`).  Order by the revenue.

# %%
Querya='''
select * from order_details
LIMIT 2
'''
Q(Querya,con=conn)
# Out:
#    OrderID  ProductID  UnitPrice  Quantity  Discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0

# %%
Query7='''
select "OrderID",COUNT("OrderID"),
SUM("UnitPrice"* "Quantity") as "revenue"
from order_details
group by "OrderID"
order by "revenue"
'''
Q(Query7,con=conn)
# Out:
#      OrderID  count       revenue
# 0      10782      1     12.500000
# 1      10807      1     18.400000
# 2      10767      1     28.000000
# 3      10586      1     28.000000
# 4      10898      1     30.000000
# 5      10883      1     36.000000
# 6      10815      1     40.000000
# 7      10674      1     45.000000
# 8      11057      1     45.000000
# 9      11051      1     45.000000
# 10     10900      1     45.000000
# 11     10271      1     48.000000
# 12     10422      1     49.799999
# 13     10738      1     52.350002
# 14     10754      1     55.199999
# 15     10620      2     57.500000
# 16     11037      1     60.000000
# 17     10631      1     62.000000
# 18     10683      1     63.000000
# 19     10602      1     65.000000
# 20     10963      1     68.000000
# 21     10992      1     69.599998
# 22     10887      1     70.000000
# 23     10589      1     72.000000
# 24     11019      2     76.000000
# 25     10391      1     86.400003
# 26     10281      3     86.499998
# 27     11067      1     86.849997
# 28     10753      2     88.000000
# 29     10331      1     88.500001
# ..       ...    ...           ...
# 800    10847      6   6164.899998
# 801    10687      3   6201.900009
# 802    10595      3   6300.000000
# 803    10612      5   6375.000000
# 804    10895      4   6379.399965
# 805    10607      5   6475.399975
# 806    10633      4   6483.049923
# 807    10993      2   6527.250032
# 808    11017      3   6750.000000
# 809    11021      5   6941.489944
# 810    10776      4   6984.500000
# 811    10360      5   7390.200079
# 812    10912      2   8267.400055
# 813    10514      5   8623.449917
# 814    10816      2   8890.999985
# 815    11032      3   8902.500000
# 816    10691      5  10164.800018
# 817    10540      4  10191.699982
# 818    10479      4  10495.600124
# 819    10515      5  10588.500221
# 820    10353      2  10741.600143
# 821    10897      2  10835.240051
# 822    10417      4  11283.200140
# 823    10889      2  11380.000000
# 824    10817      4  11490.699940
# 825    10424      3  11493.200127
# 826    10372      4  12281.200180
# 827    10981      1  15810.000000
# 828    11030      4  16321.900082
# 829    10865      2  17250.000000
#
# [830 rows x 3 columns]

# %% [markdown]
# <a id='having'></a>
# ## The `HAVING` operator
#
# ---
#
# The `HAVING` clause was added to SQL because the `WHERE` keyword could not be used with aggregate functions. `HAVING` allows us to apply a filter to the aggregate functions. For example, if we only wanted to show companies that had revenue (calculated with an aggregate function) greater than $10,000.
#
# ### `HAVING` Syntax
#
# ``` *.sql
#
# SELECT column_name, aggregate_function(column_name)
# FROM table_name
# WHERE column_name operator value
# GROUP BY column_name
# HAVING aggregate_function(column_name) operator value;
#
# ```

# %% [markdown]
# ### Exercise 8
#
# Show the revenue of all orders that have more than 1 item.

# %%
Query8='''
select "OrderID",COUNT("OrderID"),
SUM("UnitPrice"* "Quantity") as "revenue"
from order_details
group by "OrderID"
Having COUNT("OrderID")>1
order by "revenue"

'''
Q8(Query,con=conn)
# Out:
#      OrderID  count       revenue
# 0      10620      2     57.500000
# 1      11019      2     76.000000
# 2      10281      3     86.499998
# 3      10753      2     88.000000
# 4      10308      2     88.799999
# 5      10288      2     89.000001
# 6      10710      2     93.499999
# 7      10259      2    100.799999
# 8      10415      2    102.400002
# 9      10366      2    135.999994
# 10     10928      2    137.500000
# 11     10737      2    139.799995
# 12     10538      2    139.799999
# 13     10334      2    144.799999
# 14     10352      2    154.000001
# 15     10282      2    155.400005
# 16     10462      2    155.999996
# 17     10870      2    160.000000
# 18     10323      3    164.399996
# 19     10386      2    165.999997
# 20     10445      2    174.899999
# 21     10708      2    180.400002
# 22     10476      2    182.400002
# 23     10810      3    187.000000
# 24     10793      2    191.099995
# 25     10520      2    199.999996
# 26     10466      2    215.999994
# 27     10521      3    225.499996
# 28     10775      2    228.000000
# 29     10473      2    230.400009
# ..       ...    ...           ...
# 663    10324      5   6155.899855
# 664    10847      6   6164.899998
# 665    10687      3   6201.900009
# 666    10595      3   6300.000000
# 667    10612      5   6375.000000
# 668    10895      4   6379.399965
# 669    10607      5   6475.399975
# 670    10633      4   6483.049923
# 671    10993      2   6527.250032
# 672    11017      3   6750.000000
# 673    11021      5   6941.489944
# 674    10776      4   6984.500000
# 675    10360      5   7390.200079
# 676    10912      2   8267.400055
# 677    10514      5   8623.449917
# 678    10816      2   8890.999985
# 679    11032      3   8902.500000
# 680    10691      5  10164.800018
# 681    10540      4  10191.699982
# 682    10479      4  10495.600124
# 683    10515      5  10588.500221
# 684    10353      2  10741.600143
# 685    10897      2  10835.240051
# 686    10417      4  11283.200140
# 687    10889      2  11380.000000
# 688    10817      4  11490.699940
# 689    10424      3  11493.200127
# 690    10372      4  12281.200180
# 691    11030      4  16321.900082
# 692    10865      2  17250.000000
#
# [693 rows x 3 columns]

# %% [markdown]
# <a id='case'></a>
# ## `CASE` statements
#
# ---
#
# The `CASE` statement is SQL’s way of applying if/then logic. The `CASE` statement is followed by at least one pair of `WHEN` and `THEN` statements. It must end with the `END` statement. The `ELSE` statement is optional, and provides a way to capture values not specified in the `WHEN/THEN` statements.
#
# ### `CASE` syntax
#
# ```*.sql
# SELECT
#     CASE WHEN column_name operator value THEN 'string value'
#         WHEN column_name operator value THEN 'string value'
#         ELSE 'string value' END AS 'alias'
# FROM table_name
# ```
#
# ### Pseudo example
#
# ```*.sql
# SELECT name
#     CASE WHEN age < 1 THEN 'infant'
#          WHEN age < 2 THEN 'toddler'
#          WHEN age < 5 THEN 'child'
#          ELSE 'old as dirt' END AS 'Persons Age'
# ```

# %% [markdown]
# ### Exercise 9
#
# Select `CompanyName`, `City`, and `Country` from the `Suppliers` table. Add a new column `D_F` which has a value of "domestic" if the supplier is from USA and "foreign" otherwise.

# %%
# A:
Queryb='''
select * from Suppliers
LIMIT 2
'''
Q(Queryb,con=conn)
# Out:
#    SupplierID                 CompanyName       ContactName  \
# 0           1              Exotic Liquids  Charlotte Cooper
# 1           2  New Orleans Cajun Delights     Shelley Burke
#
#           ContactTitle         Address         City Region PostalCode Country  \
# 0   Purchasing Manager  49 Gilbert St.       London   None    EC1 4SD      UK
# 1  Order Administrator  P.O. Box 78934  New Orleans     LA      70117     USA
#
#             Phone   Fax     HomePage
# 0  (171) 555-2222  None         None
# 1  (100) 555-4822  None  #CAJUN.HTM#

# %%
Query9='''
select "CompanyName","City","Country",
    CASE when "Country" like 'USA' THEN 'DOMESTIC'
    ELSE 'FORIEGN' END AS "D_F"
    FROM SUPPLIERS
'''
Q(Query9,con=conn)
# Out:
#                                CompanyName           City      Country  \
# 0                           Exotic Liquids         London           UK
# 1               New Orleans Cajun Delights    New Orleans          USA
# 2                Grandma Kelly's Homestead      Ann Arbor          USA
# 3                            Tokyo Traders          Tokyo        Japan
# 4       Cooperativa de Quesos 'Las Cabras'         Oviedo        Spain
# 5                                 Mayumi's          Osaka        Japan
# 6                            Pavlova, Ltd.      Melbourne    Australia
# 7                 Specialty Biscuits, Ltd.     Manchester           UK
# 8                         PB Knäckebröd AB       Göteborg       Sweden
# 9                Refrescos Americanas LTDA      Sao Paulo       Brazil
# 10             Heli Süßwaren GmbH & Co. KG         Berlin      Germany
# 11       Plutzer Lebensmittelgroßmärkte AG      Frankfurt      Germany
# 12  Nord-Ost-Fisch Handelsgesellschaft mbH       Cuxhaven      Germany
# 13                 Formaggi Fortini s.r.l.        Ravenna        Italy
# 14                         Norske Meierier       Sandvika       Norway
# 15                       Bigfoot Breweries           Bend          USA
# 16                       Svensk Sjöföda AB      Stockholm       Sweden
# 17              Aux joyeux ecclésiastiques          Paris       France
# 18             New England Seafood Cannery         Boston          USA
# 19                            Leka Trading      Singapore    Singapore
# 20                              Lyngbysild         Lyngby      Denmark
# 21                     Zaanse Snoepfabriek        Zaandam  Netherlands
# 22                               Karkki Oy   Lappeenranta      Finland
# 23                             G'day, Mate         Sydney    Australia
# 24                               Ma Maison       Montréal       Canada
# 25                    Pasta Buttini s.r.l.        Salerno        Italy
# 26                      Escargots Nouveaux       Montceau       France
# 27                            Gai pâturage         Annecy       France
# 28                        Forêts d'érables  Ste-Hyacinthe       Canada
#
#          D_F
# 0    FORIEGN
# 1   DOMESTIC
# 2   DOMESTIC
# 3    FORIEGN
# 4    FORIEGN
# 5    FORIEGN
# 6    FORIEGN
# 7    FORIEGN
# 8    FORIEGN
# 9    FORIEGN
# 10   FORIEGN
# 11   FORIEGN
# 12   FORIEGN
# 13   FORIEGN
# 14   FORIEGN
# 15  DOMESTIC
# 16   FORIEGN
# 17   FORIEGN
# 18  DOMESTIC
# 19   FORIEGN
# 20   FORIEGN
# 21   FORIEGN
# 22   FORIEGN
# 23   FORIEGN
# 24   FORIEGN
# 25   FORIEGN
# 26   FORIEGN
# 27   FORIEGN
# 28   FORIEGN

# %% [markdown]
# <a id='dates'></a>
# ## Working with dates
#
# ---
#
# [Take some time to look over the postgres date documentation](https://www.postgresql.org/docs/8.1/static/functions-datetime.html)
#
# ### Extracting date parts from a date object
# ```*.sql
# SELECT my_date,
#        EXTRACT('year'   FROM my_date) AS year,
#        EXTRACT('month'  FROM my_date) AS month,
#        EXTRACT('day'    FROM my_date) AS day,
#        EXTRACT('hour'   FROM my_date) AS hour,
#        EXTRACT('minute' FROM my_date) AS minute,
#        EXTRACT('second' FROM my_date) AS second,
#        EXTRACT('decade' FROM my_date) AS decade,
#        EXTRACT('dow'    FROM my_date) AS day_of_week
#   FROM table_name
# ```

# %% [markdown]
# ### Exercise 10
#
# Select `OrderDate` and `Freight` from the `Orders` table, along with three new columns for Year, Month, and Day. Make sure these are [cast as integers and not floats](http://www.postgresqltutorial.com/postgresql-cast/).
#
# After extracting the dates as integers, pull out the year, month, and sum of `Freight` aliased as "FreightPerMonth", grouping by the year and month and only where the freight per month is greater than 5000.
#
# Order this datagrame by year and month descending.

# %%
# A:
Query10='''
select "year","month",SUM("Freight") as "FreightPerMonth"
       from(select
       "OrderDate",
       cast(EXTRACT('year' FROM "OrderDate")as int) AS year,
       cast(EXTRACT('month'FROM "OrderDate")as int) AS month,
       cast(EXTRACT('day' FROM "OrderDate")as int) AS day,
       "Freight"
    from Orders) as sub
       group by year,month
       having SUM("Freight") >5000
       order by year desc,month desc

'''
Q(Query10,con=conn)
# Out:
#    year  month  FreightPerMonth
# 0  1998      4          6393.57
# 1  1998      3          5379.02
# 2  1998      1          5463.44

# %% [markdown]
# <a id='additional-exercises'></a>
#
# ### Exercise 11
#
# From the `orders` table find the average number of days it took to ship a package per `ShipCountry`. Only include orders that have a ship date, and only show the top 5.

# %%
queryc='''
select * from orders
limit 2
'''
Q(queryc,con=conn)
# Out:
#    OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
#
#    ShipVia  Freight                   ShipName         ShipAddress ShipCity  \
# 0        3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1        1    11.61         Toms Spezialitäten       Luisenstr. 48  Münster
#
#   ShipRegion ShipPostalCode ShipCountry
# 0       None          51100      France
# 1       None          44087     Germany

# %%
query11='''
select AVG("ShippedDate"-"OrderDate") As "Avg_no_days_shipping",
"ShipCountry"
from orders
where "ShippedDate" is not null
group by "ShipCountry"
order by AVG("ShippedDate"-"OrderDate") desc
Limit 5
'''
Q(query11,con=conn)
# Out:
#    Avg_no_days_shipping  ShipCountry
# 0             11.000000      Ireland
# 1             10.216216       Sweden
# 2              9.941176  Switzerland
# 3              9.554622          USA
# 4              9.285714    Argentina

# %% [markdown]
# ### Exercise 12
#
# Find the top 5 countries by average freight cost of products shipped in the year 1998 from the `orders` table.

# %%
query12='''
select AVG("Freight") as "average_freigt_cost","ShipCountry"
from orders
where Extract('year' from "ShippedDate") = 1998
group by "ShipCountry"
order by AVG("Freight") DESC
limit 5
'''
Q(query12,con=conn)
# Out:
#    average_freigt_cost ShipCountry
# 0           339.422489     Ireland
# 1           199.137275     Austria
# 2           166.906216         USA
# 3           131.617501     Denmark
# 4           102.470003    Portugal

# %% [markdown]
# ### Exercise 13
#
# From the `employees` table find the 2 women that were hired the most recently. Exclude employees where the gender is ambiguous.

# %%
Query_d='''
select * from employees
limit  1
'''
Q(Query_d,con=conn)
# Out:
#    EmployeeID LastName FirstName                 Title TitleOfCourtesy  \
# 0           1  Davolio     Nancy  Sales Representative             Ms.
#
#     BirthDate    HireDate                      Address     City Region  \
# 0  1948-12-08  1992-05-01  507 - 20th Ave. E.\nApt. 2A  Seattle     WA
#
#   PostalCode Country       HomePhone Extension Photo  \
# 0      98122     USA  (206) 555-9857      5467    []
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...          2
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
Query_e='''
select DISTINCT "TitleOfCourtesy"
from employees

'''
Q(Query_e,con=conn)
# Out:
#   TitleOfCourtesy
# 0            Mrs.
# 1             Mr.
# 2             Ms.
# 3             Dr.

# %%
query13='''
select "LastName","FirstName"
from employees
where "TitleOfCourtesy" in('Mrs.','Ms.')
order by "HireDate" desc
Limit 2
'''
Q(query13,con=conn)
# Out:
#     LastName FirstName
# 0  Dodsworth      Anne
# 1   Callahan     Laura

# %% [markdown]
# ### Exercise 14
#
# Split products from the `Products` table into three price categories:
# - Cheap: less than 10
# - Fair: 10 to 50
# - Expensive: greater than 50
#
# Return the count per product price categories along with the min, max, and average.

# %%
queryf='''
select * from Products
limit 1
'''
Q(queryf,con=conn)
# Out:
#    ProductID ProductName  SupplierID  CategoryID     QuantityPerUnit  \
# 0          1        Chai           8           1  10 boxes x 30 bags
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0       18.0            39             0            10             1

# %%
query14='''
select "Price_Indicator",count("Price_Indicator"),min("UnitPrice"),max("UnitPrice"),avg("UnitPrice")
from(select "UnitPrice",
 case
    when "UnitPrice"<10
    then 'cheap'
    when "UnitPrice" IN (10,50)
    then 'fair'
    else 'expensive' END as "Price_Indicator"

from Products) as origin
group by origin."Price_Indicator"
'''
Q(query14,con=conn)
# Out:
#   Price_Indicator  count   min     max        avg
# 0           cheap     11   2.5    9.65   7.459091
# 1       expensive     63  12.0  263.50  33.462857
# 2            fair      3  10.0   10.00  10.000000

# %% [markdown]
# <a id='conclusion'></a>
# ## Conclusion
#
# ---
#
# In this lesson we have learned many new commands to make powerful SQL queries.
#
# In particular we learned how to:
#
# - Sort results by a column using `ORDER BY`
# - Simplify our syntax using aliases
# - Match patterns using `LIKE`
# - Select distinct items using `DISTINCT`
# - Aggregate values using `GROUP BY`
# - Filter on aggregations using `HAVING`
# - Apply `IF/THEN` logic using `CASE`
# - Use `EXTRACT` to get date parts
#
# **Can you think of a few more business cases where these are useful?**

# %% [markdown]
# <a id='additional-resources'></a>
# ## Additional resources
#
# ---
#
# - [Postgres Documenation](https://www.postgresql.org/docs/)
# - [Mode Analytics Tutorial](https://community.modeanalytics.com/sql/tutorial/introduction-to-sql/)
