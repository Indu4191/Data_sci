# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
wine=pd.read_csv('/Users/Mahendra/desktop/GA/hw/5.2.2_regression-regularization-lesson/datasets/winequality_merged.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# ...

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
# ...

# %%
def correlation_heat_map(wine):
    corrs = wine.corr()

    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(15,11))

    # Generate a mask for the upper triangle (taken from seaborn example gallery)
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with seaborn.
    # Assign the matplotlib axis the function returns. This will let us resize the labels.
    ax = sns.heatmap(corrs, mask=mask, annot=True)

    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=30)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)

    # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
    plt.show()
df_with_target = wine.copy()
correlation_heat_map(wine)

# %%
target='quality'

# %%
nc = [x for x in wine.columns if x != target]

# %%
wine.ix[:, nc] = (wine.ix[:, nc] - wine.ix[:, nc].mean()) / wine.ix[:, nc].std()

# %%
wine.ix[:, nc]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.142462          2.188664    -2.192664       -0.744721   0.569914
# 1          0.451001          3.281982    -2.192664       -0.597594   1.197883
# 2          0.451001          2.553104    -1.917405       -0.660648   1.026618
# 3          3.073580         -0.362411     1.660957       -0.744721   0.541370
# 4          0.142462          2.188664    -2.192664       -0.744721   0.569914
# 5          0.142462          1.945705    -2.192664       -0.765739   0.541370
# 6          0.528136          1.581266    -1.779776       -0.807775   0.370106
# 7          0.065328          1.884965    -2.192664       -0.891847   0.255930
# 8          0.451001          1.459786    -2.055034       -0.723703   0.484282
# 9          0.219597          0.973867     0.284664        0.138039   0.427194
# 10        -0.397480          1.459786    -1.642146       -0.765739   1.169338
# ...
