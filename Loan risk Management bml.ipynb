# %%
BigML.com
PRIVATE DEPLOYMENTS
GALLERY
EXPLABS
INDU4191
DOCUMENTATION
HELP & SUPPORT
Dashboard
      
BIGML
SCRIPTS0
MODELS19
DATASETS19
0 4831
FREE
Loan Risk
136.7 KB
size
19
fields
1,000
instances
Details:
Fields:
Description:
Model that will predict the quality of risk of a loan application. This dataset was initially created by dr. Hans Hofmann at the Institut fur Statistik und Okonometrie Universitat Hamburg.

 

Tags:
Finance Risk Analysis Loan
URL:
http://bml.io/RaEGSc
Buy FREE

class: ?
?
 
SUPPORT
0.1 %  9.1 %  
Predictions for: class

 
CONFIDENCE
0 %  100 %   
RELATED MODELS
Banking & Finance
Loan risk data model
0.00
Loan risk data model
Average Equal Weighted Returns
FREE
Average Equal Weighted Returns
Average Value Weighted Returns
FREE
Average Value Weighted Returns
Caja Madrid black credit cards: amounts
FREE
Caja Madrid black credit cards: amounts
Caja Madrid black credit cards: Text analysis
FREE
Caja Madrid black credit cards: Text analysis
Caja Madrid black credit cards
FREE
Caja Madrid black credit cards
BIGML
Text Classification Model
FREE
Text Classification Model
SC Cases' dataset model
FREE
SC Cases' dataset model
solar_power_data's dataset model
FREE
solar_power_data's dataset model
The Voice highest level reached
FREE
The Voice highest level reached
London Borough Profile Analysis
FREE
London Borough Profile Analysis
Waiting List and Housing Tenure
FREE
Waiting List and Housing Tenure

COMPANY
About
Blog
Contact
Openings
Team
PRODUCT
API
Releases
Tools
What's New
WhizzML
BUSINESS
Certifications
Education
Events
Pricing
Private Deployments
GALLERY
Datasets
Models
Scripts
Follow us on:
Terms of Service Privacy Policy FAQ
Copyright © 2017 BigML, Inc.


×
Actionable Model Download


Complete actionable model:
Python

Only rules up to the selected node:
Select the language

 htmlpop-up
def predict_class(data={}):
    """ Predictor for class from model/4f89c39b1552686458000038

        Model that will predict the quality of risk of a loan application. This dataset was initially created by dr. Hans Hofmann at the Institut fur Statistik und Okonometrie Universitat Hamburg.
    """
    if (data.get('checking_status') is None):
        return u'good'
    if (data['checking_status'] == '>=200'):
        if (data.get('property_magnitude') is None):
            return u'good'
        if (data['property_magnitude'] == 'car'):
            if (data.get('employment') is None):
                return u'good'
            if (data['employment'] == '1<=X<4'):
                if (data.get('credit_amount') is None):
                    return u'good'
                if (data['credit_amount'] > 3082.0):
                    if (data.get('credit_history') is None):
                        return u'good'
                    if (data['credit_history'] != 'existing paid'):
                        return u'good'
                    if (data['credit_history'] == 'existing paid'):
                        if (data['credit_amount'] > 5029.0):
                            return u'good'
                        if (data['credit_amount'] <= 5029.0):
                            return u'bad'
                if (data['credit_amount'] <= 3082.0):
                    return u'good'
            if (data['employment'] == '>=7'):
                return u'good'
            if (data['employment'] == '4<=X<7'):
                return u'good'
            if (data['employment'] == '<1'):
                if (data.get('credit_history') is None):
                    return u'bad'
                if (data['credit_history'] != 'existing paid'):
                    return u'bad'
                if (data['credit_history'] == 'existing paid'):
                    return u'good'
        if (data['property_magnitude'] == 'life insurance'):
            return u'good'
        if (data['property_magnitude'] == 'real estate'):
            if (data.get('savings_status') is None):
                return u'good'
            if (data['savings_status'] == '500<=X<1000'):
                return u'bad'
            if (data['savings_status'] == 'no known savings'):
                if (data.get('credit_history') is None):
                    return u'good'
                if (data['credit_history'] != 'existing paid'):
                    return u'bad'
                if (data['credit_history'] == 'existing paid'):
                    return u'good'
            if (data['savings_status'] == '100<=X<500'):
                return u'good'
            if (data['savings_status'] == '>=1000'):
                return u'good'
            if (data['savings_status'] == '<100'):
                if (data.get('job') is None):
                    return u'good'
                if (data['job'] == 'unskilled resident'):
                    return u'bad'
                if (data['job'] == 'unemp/unskilled non res'):
                    if (data.get('credit_history') is None):
                        return u'bad'
                    if (data['credit_history'] != 'all paid'):
                        return u'good'
                    if (data['credit_history'] == 'all paid'):
                        return u'bad'
                if (data['job'] == 'high qualif/self emp/mgmt'):
                    return u'bad'
                if (data['job'] == 'skilled'):
                    if (data.get('other_parties') is None):
                        return u'good'
                    if (data['other_parties'] != 'none'):
                        return u'bad'
                    if (data['other_parties'] == 'none'):
                        return u'good'
        if (data['property_magnitude'] == 'no known property'):
            if (data.get('employment') is None):
                return u'good'
            if (data['employment'] == '1<=X<4'):
                return u'bad'
            if (data['employment'] == '4<=X<7'):
                return u'bad'
            if (data['employment'] == 'unemployed'):
                return u'good'
            if (data['employment'] == '>=7'):
                if (data.get('job') is None):
                    return u'good'
                if (data['job'] != 'skilled'):
                    return u'bad'
                if (data['job'] == 'skilled'):
                    return u'good'
    if (data['checking_status'] == '<0'):
        if (data.get('credit_history') is None):
            return u'good'
        if (data['credit_history'] == 'delayed previously'):
            if (data.get('duration') is None):
                return u'bad'
            if (data['duration'] > 19.5):
                return u'bad'
            if (data['duration'] <= 19.5):
                return u'good'
        if (data['credit_history'] == 'no credits/all paid'):
            if (data.get('housing') is None):
                return u'bad'
            if (data['housing'] != 'own'):
                return u'bad'
            if (data['housing'] == 'own'):
                if (data.get('purpose') is None):
                    return u'good'
                if (data['purpose'] == 'repairs'):
                    return u'bad'
                if (data['purpose'] == 'new car'):
                    return u'bad'
                if (data['purpose'] == 'furniture/equipment'):
                    return u'good'
                if (data['purpose'] == 'business'):
                    if (data.get('employment') is None):
                        return u'good'
                    if (data['employment'] != 'unemployed'):
                        return u'good'
                    if (data['employment'] == 'unemployed'):
                        return u'bad'
        if (data['credit_history'] == 'all paid'):
            if (data.get('purpose') is None):
                return u'bad'
            if (data['purpose'] == 'education'):
                return u'bad'
            if (data['purpose'] == 'business'):
                return u'bad'
            if (data['purpose'] == 'other'):
                return u'bad'
            if (data['purpose'] == 'used car'):
                return u'good'
            if (data['purpose'] == 'retraining'):
                return u'good'
            if (data['purpose'] == 'radio/tv'):
                if (data.get('employment') is None):
                    return u'bad'
                if (data['employment'] != '<1'):
                    return u'bad'
                if (data['employment'] == '<1'):
                    return u'good'
            if (data['purpose'] == 'furniture/equipment'):
                if (data.get('property_magnitude') is None):
                    return u'bad'
                if (data['property_magnitude'] != 'real estate'):
                    return u'bad'
                if (data['property_magnitude'] == 'real estate'):
                    return u'good'
            if (data['purpose'] == 'new car'):
                if (data.get('savings_status') is None):
                    return u'bad'
                if (data['savings_status'] != '100<=X<500'):
                    return u'bad'
                if (data['savings_status'] == '100<=X<500'):
                    return u'good'
        if (data['credit_history'] == 'existing paid'):
            if (data.get('purpose') is None):
                return u'bad'
            if (data['purpose'] == 'business'):
                if (data.get('employment') is None):
                    return u'good'
                if (data['employment'] != '1<=X<4'):
                    return u'bad'
                if (data['employment'] == '1<=X<4'):
                    return u'good'
            if (data['purpose'] == 'repairs'):
                return u'bad'
            if (data['purpose'] == 'education'):
                if (data.get('employment') is None):
                    return u'bad'
                if (data['employment'] == 'unemployed'):
                    return u'bad'
                if (data['employment'] == '>=7'):
                    return u'bad'
                if (data['employment'] == '4<=X<7'):
                    return u'good'
                if (data['employment'] == '<1'):
                    return u'bad'
                if (data['employment'] == '1<=X<4'):
                    if (data.get('savings_status') is None):
                        return u'good'
                    if (data['savings_status'] != 'no known savings'):
                        return u'bad'
                    if (data['savings_status'] == 'no known savings'):
                        return u'good'
            if (data['purpose'] == 'domestic appliance'):
                if (data.get('employment') is None):
                    return u'bad'
                if (data['employment'] != '<1'):
                    return u'bad'
                if (data['employment'] == '<1'):
                    return u'good'
            if (data['purpose'] == 'retraining'):
                return u'bad'
            if (data['purpose'] == 'other'):
                return u'good'
            if (data['purpose'] == 'used car'):
                if (data.get('credit_amount') is None):
                    return u'good'
                if (data['credit_amount'] > 7045.0):
                    return u'bad'
                if (data['credit_amount'] <= 7045.0):
                    if (data.get('employment') is None):
                        return u'good'
                    if (data['employment'] != '>=7'):
                        return u'good'
                    if (data['employment'] == '>=7'):
                        if (data.get('duration') is None):
                            return u'good'
                        if (data['duration'] > 18.0):
                            return u'good'
                        if (data['duration'] <= 18.0):
                            return u'bad'
            if (data['purpose'] == 'furniture/equipment'):
                if (data.get('duration') is None):
                    return u'good'
                if (data['duration'] > 16.5):
                    if (data.get('credit_amount') is None):
                        return u'bad'
                    if (data['credit_amount'] > 3522.5):
                        if (data['credit_amount'] > 4086.5):
                            if (data.get('employment') is None):
                                return u'good'
                            if (data['employment'] == '>=7'):
                                return u'bad'
                            if (data['employment'] == '<1'):
                                return u'good'
                            if (data['employment'] == '1<=X<4'):
                                if (data.get('other_parties') is None):
                                    return u'bad'
                                if (data['other_parties'] != 'co applicant'):
                                    return u'good'
                                if (data['other_parties'] == 'co applicant'):
                                    return u'bad'
                            if (data['employment'] == '4<=X<7'):
                                if (data.get('other_parties') is None):
                                    return u'good'
                                if (data['other_parties'] != 'guarantor'):
                                    return u'bad'
                                if (data['other_parties'] == 'guarantor'):
                                    return u'good'
                        if (data['credit_amount'] <= 4086.5):
                            return u'good'
                    if (data['credit_amount'] <= 3522.5):
                        if (data.get('employment') is None):
                            return u'bad'
                        if (data['employment'] == 'unemployed'):
                            return u'bad'
                        if (data['employment'] == '4<=X<7'):
                            if (data.get('savings_status') is None):
                                return u'bad'
                            if (data['savings_status'] != '<100'):
                                return u'good'
                            if (data['savings_status'] == '<100'):
                                return u'bad'
                        if (data['employment'] == '<1'):
                            if (data.get('personal_status') is None):
                                return u'good'
                            if (data['personal_status'] != 'male single'):
                                return u'bad'
                            if (data['personal_status'] == 'male single'):
                                return u'good'
                        if (data['employment'] == '>=7'):
                            return u'bad'
                        if (data['employment'] == '1<=X<4'):
                            if (data.get('age') is None):
                                return u'bad'
                            if (data['age'] > 23.0):
                                return u'good'
                            if (data['age'] <= 23.0):
                                return u'bad'
                if (data['duration'] <= 16.5):
                    if (data.get('property_magnitude') is None):
                        return u'good'
                    if (data['property_magnitude'] == 'no known property'):
                        if (data.get('employment') is None):
                            return u'bad'
                        if (data['employment'] != '>=7'):
                            return u'good'
                        if (data['employment'] == '>=7'):
                            return u'bad'
                    if (data['property_magnitude'] == 'life insurance'):
                        return u'good'
                    if (data['property_magnitude'] == 'car'):
                        if (data.get('credit_amount') is None):
                            return u'good'
                        if (data['credit_amount'] > 1570.0):
                            return u'good'
                        if (data['credit_amount'] <= 1570.0):
                            return u'bad'
                    if (data['property_magnitude'] == 'real estate'):
                        return u'good'
            if (data['purpose'] == 'new car'):
                if (data.get('savings_status') is None):
                    return u'bad'
                if (data['savings_status'] == '>=1000'):
                    return u'good'
                if (data['savings_status'] == '100<=X<500'):
                    return u'good'
                if (data['savings_status'] == 'no known savings'):
                    if (data.get('job') is None):
                        return u'bad'
                    if (data['job'] != 'skilled'):
                        return u'good'
                    if (data['job'] == 'skilled'):
                        return u'bad'
                if (data['savings_status'] == '<100'):
                    if (data.get('employment') is None):
                        return u'bad'
                    if (data['employment'] == '>=7'):
                        return u'bad'
                    if (data['employment'] == '1<=X<4'):
                        if (data.get('personal_status') is None):
                            return u'bad'
                        if (data['personal_status'] == 'male single'):
                            return u'bad'
                        if (data['personal_status'] == 'male mar/wid'):
                            return u'good'
                        if (data['personal_status'] == 'female div/dep/mar'):
                            if (data.get('property_magnitude') is None):
                                return u'bad'
                            if (data['property_magnitude'] == 'car'):
                                return u'good'
                            if (data['property_magnitude'] == 'life insurance'):
                                if (data.get('other_parties') is None):
                                    return u'bad'
                                if (data['other_parties'] != 'none'):
                                    return u'good'
                                if (data['other_parties'] == 'none'):
                                    return u'bad'
                            if (data['property_magnitude'] == 'real estate'):
                                return u'bad'
                    if (data['employment'] == '4<=X<7'):
                        if (data.get('other_payment_plans') is None):
                            return u'bad'
                        if (data['other_payment_plans'] != 'none'):
                            return u'good'
                        if (data['other_payment_plans'] == 'none'):
                            return u'bad'
                    if (data['employment'] == '<1'):
                        if (data.get('age') is None):
                            return u'bad'
                        if (data['age'] > 34.5):
                            if (data.get('personal_status') is None):
                                return u'good'
                            if (data['personal_status'] != 'female div/dep/mar'):
                                return u'good'
                            if (data['personal_status'] == 'female div/dep/mar'):
                                if (data.get('own_telephone') is None):
                                    return u'bad'
                                if (data['own_telephone'] != 'none'):
                                    return u'good'
                                if (data['own_telephone'] == 'none'):
                                    return u'bad'
                        if (data['age'] <= 34.5):
                            return u'bad'
                    if (data['employment'] == 'unemployed'):
                        return u'good'
            if (data['purpose'] == 'radio/tv'):
                if (data.get('savings_status') is None):
                    return u'bad'
                if (data['savings_status'] == '>=1000'):
                    return u'good'
                if (data['savings_status'] == 'no known savings'):
                    if (data.get('personal_status') is None):
                        return u'good'
                    if (data['personal_status'] != 'male mar/wid'):
                        return u'bad'
                    if (data['personal_status'] == 'male mar/wid'):
                        return u'good'
                if (data['savings_status'] == '500<=X<1000'):
                    return u'good'
                if (data['savings_status'] == '100<=X<500'):
                    return u'bad'
                if (data['savings_status'] == '<100'):
                    if (data.get('duration') is None):
                        return u'bad'
                    if (data['duration'] > 33.0):
                        return u'bad'
                    if (data['duration'] <= 33.0):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] == 'unemployed'):
                            return u'bad'
                        if (data['employment'] == '>=7'):
                            if (data.get('other_payment_plans') is None):
                                return u'good'
                            if (data['other_payment_plans'] != 'stores'):
                                return u'good'
                            if (data['other_payment_plans'] == 'stores'):
                                return u'bad'
                        if (data['employment'] == '4<=X<7'):
                            return u'good'
                        if (data['employment'] == '<1'):
                            if (data.get('personal_status') is None):
                                return u'bad'
                            if (data['personal_status'] == 'male mar/wid'):
                                return u'good'
                            if (data['personal_status'] == 'male div/sep'):
                                return u'bad'
                            if (data['personal_status'] == 'female div/dep/mar'):
                                if (data.get('property_magnitude') is None):
                                    return u'bad'
                                if (data['property_magnitude'] == 'car'):
                                    return u'good'
                                if (data['property_magnitude'] == 'real estate'):
                                    return u'bad'
                                if (data['property_magnitude'] == 'life insurance'):
                                    if (data.get('job') is None):
                                        return u'bad'
                                    if (data['job'] != 'skilled'):
                                        return u'good'
                                    if (data['job'] == 'skilled'):
                                        return u'bad'
                        if (data['employment'] == '1<=X<4'):
                            if (data.get('property_magnitude') is None):
                                return u'good'
                            if (data['property_magnitude'] == 'life insurance'):
                                return u'good'
                            if (data['property_magnitude'] == 'no known property'):
                                return u'bad'
                            if (data['property_magnitude'] == 'car'):
                                if (data.get('housing') is None):
                                    return u'good'
                                if (data['housing'] != 'own'):
                                    return u'bad'
                                if (data['housing'] == 'own'):
                                    return u'good'
                            if (data['property_magnitude'] == 'real estate'):
                                if (data.get('credit_amount') is None):
                                    return u'bad'
                                if (data['credit_amount'] > 1226.0):
                                    return u'bad'
                                if (data['credit_amount'] <= 1226.0):
                                    return u'good'
        if (data['credit_history'] == 'critical/other existing credit'):
            if (data.get('purpose') is None):
                return u'good'
            if (data['purpose'] == 'education'):
                return u'bad'
            if (data['purpose'] == 'other'):
                return u'good'
            if (data['purpose'] == 'repairs'):
                if (data.get('personal_status') is None):
                    return u'good'
                if (data['personal_status'] != 'female div/dep/mar'):
                    return u'good'
                if (data['personal_status'] == 'female div/dep/mar'):
                    return u'bad'
            if (data['purpose'] == 'business'):
                return u'good'
            if (data['purpose'] == 'radio/tv'):
                return u'good'
            if (data['purpose'] == 'used car'):
                if (data.get('duration') is None):
                    return u'good'
                if (data['duration'] > 33.0):
                    return u'bad'
                if (data['duration'] <= 33.0):
                    return u'good'
            if (data['purpose'] == 'furniture/equipment'):
                if (data.get('credit_amount') is None):
                    return u'good'
                if (data['credit_amount'] > 1998.0):
                    if (data.get('property_magnitude') is None):
                        return u'good'
                    if (data['property_magnitude'] == 'car'):
                        return u'bad'
                    if (data['property_magnitude'] == 'no known property'):
                        return u'bad'
                    if (data['property_magnitude'] == 'real estate'):
                        if (data.get('savings_status') is None):
                            return u'bad'
                        if (data['savings_status'] != '<100'):
                            return u'good'
                        if (data['savings_status'] == '<100'):
                            return u'bad'
                    if (data['property_magnitude'] == 'life insurance'):
                        if (data.get('duration') is None):
                            return u'good'
                        if (data['duration'] > 16.0):
                            return u'good'
                        if (data['duration'] <= 16.0):
                            return u'bad'
                if (data['credit_amount'] <= 1998.0):
                    return u'good'
            if (data['purpose'] == 'new car'):
                if (data.get('duration') is None):
                    return u'good'
                if (data['duration'] > 11.5):
                    if (data.get('other_parties') is None):
                        return u'bad'
                    if (data['other_parties'] != 'none'):
                        return u'bad'
                    if (data['other_parties'] == 'none'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] != '1<=X<4'):
                            if (data.get('personal_status') is None):
                                return u'good'
                            if (data['personal_status'] == 'male single'):
                                if (data.get('property_magnitude') is None):
                                    return u'bad'
                                if (data['property_magnitude'] == 'car'):
                                    return u'bad'
                                if (data['property_magnitude'] == 'no known property'):
                                    return u'good'
                                if (data['property_magnitude'] == 'real estate'):
                                    return u'good'
                                if (data['property_magnitude'] == 'life insurance'):
                                    return u'bad'
                            if (data['personal_status'] == 'female div/dep/mar'):
                                return u'bad'
                            if (data['personal_status'] == 'male mar/wid'):
                                return u'good'
                        if (data['employment'] == '1<=X<4'):
                            return u'good'
                if (data['duration'] <= 11.5):
                    return u'good'
    if (data['checking_status'] == '0<=X<200'):
        if (data.get('credit_amount') is None):
            return u'good'
        if (data['credit_amount'] > 12492.25):
            return u'bad'
        if (data['credit_amount'] <= 12492.25):
            if (data.get('savings_status') is None):
                return u'good'
            if (data['savings_status'] == '>=1000'):
                if (data.get('purpose') is None):
                    return u'good'
                if (data['purpose'] == 'repairs'):
                    return u'bad'
                if (data['purpose'] == 'used car'):
                    return u'good'
                if (data['purpose'] == 'radio/tv'):
                    return u'bad'
                if (data['purpose'] == 'business'):
                    return u'good'
                if (data['purpose'] == 'education'):
                    return u'bad'
                if (data['purpose'] == 'new car'):
                    return u'good'
                if (data['purpose'] == 'furniture/equipment'):
                    return u'good'
            if (data['savings_status'] == '500<=X<1000'):
                if (data.get('purpose') is None):
                    return u'good'
                if (data['purpose'] == 'new car'):
                    return u'good'
                if (data['purpose'] == 'used car'):
                    return u'bad'
                if (data['purpose'] == 'business'):
                    return u'good'
                if (data['purpose'] == 'radio/tv'):
                    if (data.get('personal_status') is None):
                        return u'good'
                    if (data['personal_status'] != 'male single'):
                        return u'good'
                    if (data['personal_status'] == 'male single'):
                        return u'bad'
            if (data['savings_status'] == 'no known savings'):
                if (data.get('credit_history') is None):
                    return u'good'
                if (data['credit_history'] != 'existing paid'):
                    return u'good'
                if (data['credit_history'] == 'existing paid'):
                    if (data.get('property_magnitude') is None):
                        return u'good'
                    if (data['property_magnitude'] == 'real estate'):
                        if (data.get('purpose') is None):
                            return u'good'
                        if (data['purpose'] == 'furniture/equipment'):
                            return u'bad'
                        if (data['purpose'] == 'new car'):
                            return u'good'
                        if (data['purpose'] == 'radio/tv'):
                            return u'bad'
                        if (data['purpose'] == 'used car'):
                            return u'good'
                    if (data['property_magnitude'] == 'car'):
                        return u'good'
                    if (data['property_magnitude'] == 'life insurance'):
                        if (data.get('purpose') is None):
                            return u'good'
                        if (data['purpose'] == 'retraining'):
                            return u'good'
                        if (data['purpose'] == 'radio/tv'):
                            return u'good'
                        if (data['purpose'] == 'furniture/equipment'):
                            if (data.get('employment') is None):
                                return u'bad'
                            if (data['employment'] != '>=7'):
                                return u'good'
                            if (data['employment'] == '>=7'):
                                return u'bad'
                        if (data['purpose'] == 'new car'):
                            return u'bad'
                    if (data['property_magnitude'] == 'no known property'):
                        if (data.get('purpose') is None):
                            return u'good'
                        if (data['purpose'] == 'education'):
                            return u'good'
                        if (data['purpose'] == 'radio/tv'):
                            return u'bad'
                        if (data['purpose'] == 'used car'):
                            return u'good'
                        if (data['purpose'] == 'new car'):
                            return u'bad'
                        if (data['purpose'] == 'other'):
                            return u'good'
            if (data['savings_status'] == '<100'):
                if (data.get('duration') is None):
                    return u'good'
                if (data['duration'] > 20.5):
                    if (data.get('purpose') is None):
                        return u'bad'
                    if (data['purpose'] == 'other'):
                        return u'bad'
                    if (data['purpose'] == 'repairs'):
                        return u'bad'
                    if (data['purpose'] == 'new car'):
                        if (data.get('property_magnitude') is None):
                            return u'bad'
                        if (data['property_magnitude'] != 'life insurance'):
                            return u'bad'
                        if (data['property_magnitude'] == 'life insurance'):
                            if (data.get('job') is None):
                                return u'good'
                            if (data['job'] != 'skilled'):
                                return u'bad'
                            if (data['job'] == 'skilled'):
                                return u'good'
                    if (data['purpose'] == 'education'):
                        if (data.get('age') is None):
                            return u'bad'
                        if (data['age'] > 33.0):
                            return u'bad'
                        if (data['age'] <= 33.0):
                            return u'good'
                    if (data['purpose'] == 'furniture/equipment'):
                        if (data.get('personal_status') is None):
                            return u'bad'
                        if (data['personal_status'] != 'male mar/wid'):
                            return u'bad'
                        if (data['personal_status'] == 'male mar/wid'):
                            return u'good'
                    if (data['purpose'] == 'business'):
                        if (data.get('employment') is None):
                            return u'bad'
                        if (data['employment'] == '<1'):
                            return u'good'
                        if (data['employment'] == '4<=X<7'):
                            return u'good'
                        if (data['employment'] == '>=7'):
                            return u'bad'
                        if (data['employment'] == '1<=X<4'):
                            if (data.get('personal_status') is None):
                                return u'bad'
                            if (data['personal_status'] != 'female div/dep/mar'):
                                return u'bad'
                            if (data['personal_status'] == 'female div/dep/mar'):
                                return u'good'
                    if (data['purpose'] == 'radio/tv'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] == '1<=X<4'):
                            return u'bad'
                        if (data['employment'] == '<1'):
                            if (data.get('property_magnitude') is None):
                                return u'bad'
                            if (data['property_magnitude'] != 'life insurance'):
                                return u'good'
                            if (data['property_magnitude'] == 'life insurance'):
                                return u'bad'
                        if (data['employment'] == '>=7'):
                            return u'good'
                        if (data['employment'] == '4<=X<7'):
                            if (data.get('property_magnitude') is None):
                                return u'bad'
                            if (data['property_magnitude'] != 'car'):
                                return u'bad'
                            if (data['property_magnitude'] == 'car'):
                                return u'good'
                    if (data['purpose'] == 'used car'):
                        if (data.get('personal_status') is None):
                            return u'good'
                        if (data['personal_status'] != 'male single'):
                            return u'bad'
                        if (data['personal_status'] == 'male single'):
                            return u'good'
                if (data['duration'] <= 20.5):
                    if (data.get('purpose') is None):
                        return u'good'
                    if (data['purpose'] == 'business'):
                        return u'good'
                    if (data['purpose'] == 'repairs'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] != '1<=X<4'):
                            return u'good'
                        if (data['employment'] == '1<=X<4'):
                            if (data.get('credit_history') is None):
                                return u'good'
                            if (data['credit_history'] != 'delayed previously'):
                                return u'bad'
                            if (data['credit_history'] == 'delayed previously'):
                                return u'good'
                    if (data['purpose'] == 'education'):
                        if (data.get('credit_history') is None):
                            return u'bad'
                        if (data['credit_history'] != 'critical/other existing credit'):
                            return u'good'
                        if (data['credit_history'] == 'critical/other existing credit'):
                            return u'bad'
                    if (data['purpose'] == 'domestic appliance'):
                        return u'good'
                    if (data['purpose'] == 'retraining'):
                        return u'good'
                    if (data['purpose'] == 'other'):
                        return u'good'
                    if (data['purpose'] == 'used car'):
                        if (data.get('credit_history') is None):
                            return u'good'
                        if (data['credit_history'] != 'all paid'):
                            return u'good'
                        if (data['credit_history'] == 'all paid'):
                            return u'bad'
                    if (data['purpose'] == 'furniture/equipment'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] == '<1'):
                            if (data.get('residence_since') is None):
                                return u'good'
                            if (data['residence_since'] > 1.5):
                                return u'bad'
                            if (data['residence_since'] <= 1.5):
                                return u'good'
                        if (data['employment'] == '1<=X<4'):
                            if (data.get('property_magnitude') is None):
                                return u'bad'
                            if (data['property_magnitude'] != 'car'):
                                return u'bad'
                            if (data['property_magnitude'] == 'car'):
                                if (data.get('foreign_worker') is None):
                                    return u'good'
                                if (data['foreign_worker'] != 'yes'):
                                    return u'bad'
                                if (data['foreign_worker'] == 'yes'):
                                    return u'good'
                        if (data['employment'] == '4<=X<7'):
                            return u'good'
                        if (data['employment'] == 'unemployed'):
                            return u'good'
                        if (data['employment'] == '>=7'):
                            if (data.get('credit_history') is None):
                                return u'good'
                            if (data['credit_history'] != 'critical/other existing credit'):
                                return u'bad'
                            if (data['credit_history'] == 'critical/other existing credit'):
                                return u'good'
                    if (data['purpose'] == 'new car'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] == '>=7'):
                            return u'bad'
                        if (data['employment'] == '<1'):
                            if (data.get('credit_history') is None):
                                return u'bad'
                            if (data['credit_history'] != 'critical/other existing credit'):
                                return u'bad'
                            if (data['credit_history'] == 'critical/other existing credit'):
                                return u'good'
                        if (data['employment'] == 'unemployed'):
                            if (data.get('credit_history') is None):
                                return u'good'
                            if (data['credit_history'] != 'delayed previously'):
                                return u'good'
                            if (data['credit_history'] == 'delayed previously'):
                                return u'bad'
                        if (data['employment'] == '4<=X<7'):
                            if (data.get('personal_status') is None):
                                return u'good'
                            if (data['personal_status'] != 'male single'):
                                return u'bad'
                            if (data['personal_status'] == 'male single'):
                                return u'good'
                        if (data['employment'] == '1<=X<4'):
                            return u'good'
                    if (data['purpose'] == 'radio/tv'):
                        if (data.get('property_magnitude') is None):
                            return u'good'
                        if (data['property_magnitude'] == 'car'):
                            if (data.get('job') is None):
                                return u'bad'
                            if (data['job'] != 'skilled'):
                                return u'good'
                            if (data['job'] == 'skilled'):
                                if (data.get('employment') is None):
                                    return u'bad'
                                if (data['employment'] != '<1'):
                                    if (data['duration'] > 13.5):
                                        return u'bad'
                                    if (data['duration'] <= 13.5):
                                        return u'good'
                                if (data['employment'] == '<1'):
                                    return u'bad'
                        if (data['property_magnitude'] == 'life insurance'):
                            return u'good'
                        if (data['property_magnitude'] == 'real estate'):
                            if (data.get('housing') is None):
                                return u'good'
                            if (data['housing'] != 'own'):
                                if (data.get('credit_history') is None):
                                    return u'good'
                                if (data['credit_history'] != 'existing paid'):
                                    return u'good'
                                if (data['credit_history'] == 'existing paid'):
                                    return u'bad'
                            if (data['housing'] == 'own'):
                                return u'good'
            if (data['savings_status'] == '100<=X<500'):
                if (data.get('purpose') is None):
                    return u'good'
                if (data['purpose'] == 'education'):
                    return u'good'
                if (data['purpose'] == 'other'):
                    return u'good'
                if (data['purpose'] == 'used car'):
                    return u'good'
                if (data['purpose'] == 'furniture/equipment'):
                    if (data.get('employment') is None):
                        return u'bad'
                    if (data['employment'] != '>=7'):
                        return u'bad'
                    if (data['employment'] == '>=7'):
                        return u'good'
                if (data['purpose'] == 'business'):
                    if (data.get('credit_history') is None):
                        return u'good'
                    if (data['credit_history'] == 'existing paid'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] != '>=7'):
                            return u'good'
                        if (data['employment'] == '>=7'):
                            return u'bad'
                    if (data['credit_history'] == 'all paid'):
                        return u'good'
                    if (data['credit_history'] == 'no credits/all paid'):
                        return u'bad'
                    if (data['credit_history'] == 'delayed previously'):
                        return u'good'
                if (data['purpose'] == 'radio/tv'):
                    if (data.get('employment') is None):
                        return u'bad'
                    if (data['employment'] == '4<=X<7'):
                        return u'good'
                    if (data['employment'] == '<1'):
                        if (data.get('installment_commitment') is None):
                            return u'bad'
                        if (data['installment_commitment'] > 2.5):
                            return u'bad'
                        if (data['installment_commitment'] <= 2.5):
                            return u'good'
                    if (data['employment'] == '1<=X<4'):
                        return u'bad'
                if (data['purpose'] == 'repairs'):
                    return u'good'
                if (data['purpose'] == 'new car'):
                    if (data.get('credit_history') is None):
                        return u'bad'
                    if (data['credit_history'] == 'critical/other existing credit'):
                        return u'good'
                    if (data['credit_history'] == 'no credits/all paid'):
                        return u'bad'
                    if (data['credit_history'] == 'all paid'):
                        return u'bad'
                    if (data['credit_history'] == 'existing paid'):
                        if (data.get('age') is None):
                            return u'bad'
                        if (data['age'] > 29.0):
                            return u'good'
                        if (data['age'] <= 29.0):
                            return u'bad'
                    if (data['credit_history'] == 'delayed previously'):
                        if (data.get('property_magnitude') is None):
                            return u'bad'
                        if (data['property_magnitude'] != 'car'):
                            return u'good'
                        if (data['property_magnitude'] == 'car'):
                            return u'bad'
    if (data['checking_status'] == 'no checking'):
        if (data.get('purpose') is None):
            return u'good'
        if (data['purpose'] == 'business'):
            if (data.get('employment') is None):
                return u'good'
            if (data['employment'] == '<1'):
                return u'bad'
            if (data['employment'] == '>=7'):
                return u'good'
            if (data['employment'] == '4<=X<7'):
                return u'good'
            if (data['employment'] == 'unemployed'):
                return u'bad'
            if (data['employment'] == '1<=X<4'):
                if (data.get('credit_history') is None):
                    return u'good'
                if (data['credit_history'] == 'critical/other existing credit'):
                    return u'good'
                if (data['credit_history'] == 'no credits/all paid'):
                    return u'bad'
                if (data['credit_history'] == 'all paid'):
                    return u'good'
                if (data['credit_history'] == 'existing paid'):
                    if (data.get('savings_status') is None):
                        return u'good'
                    if (data['savings_status'] == '>=1000'):
                        return u'bad'
                    if (data['savings_status'] == '100<=X<500'):
                        return u'good'
                    if (data['savings_status'] == 'no known savings'):
                        return u'bad'
                    if (data['savings_status'] == '<100'):
                        return u'good'
                if (data['credit_history'] == 'delayed previously'):
                    if (data.get('personal_status') is None):
                        return u'good'
                    if (data['personal_status'] != 'male mar/wid'):
                        return u'good'
                    if (data['personal_status'] == 'male mar/wid'):
                        return u'bad'
        if (data['purpose'] == 'repairs'):
            if (data.get('credit_history') is None):
                return u'good'
            if (data['credit_history'] == 'no credits/all paid'):
                return u'good'
            if (data['credit_history'] == 'delayed previously'):
                return u'bad'
            if (data['credit_history'] == 'critical/other existing credit'):
                return u'good'
            if (data['credit_history'] == 'existing paid'):
                if (data.get('savings_status') is None):
                    return u'good'
                if (data['savings_status'] != '<100'):
                    return u'good'
                if (data['savings_status'] == '<100'):
                    return u'bad'
        if (data['purpose'] == 'education'):
            if (data.get('savings_status') is None):
                return u'good'
            if (data['savings_status'] == '500<=X<1000'):
                return u'good'
            if (data['savings_status'] == '<100'):
                if (data.get('other_payment_plans') is None):
                    return u'good'
                if (data['other_payment_plans'] == 'bank'):
                    if (data.get('property_magnitude') is None):
                        return u'good'
                    if (data['property_magnitude'] != 'car'):
                        return u'good'
                    if (data['property_magnitude'] == 'car'):
                        return u'bad'
                if (data['other_payment_plans'] == 'none'):
                    return u'good'
                if (data['other_payment_plans'] == 'stores'):
                    return u'bad'
            if (data['savings_status'] == '100<=X<500'):
                if (data.get('property_magnitude') is None):
                    return u'bad'
                if (data['property_magnitude'] != 'car'):
                    return u'bad'
                if (data['property_magnitude'] == 'car'):
                    return u'good'
            if (data['savings_status'] == 'no known savings'):
                return u'good'
        if (data['purpose'] == 'domestic appliance'):
            return u'good'
        if (data['purpose'] == 'retraining'):
            return u'good'
        if (data['purpose'] == 'other'):
            return u'good'
        if (data['purpose'] == 'used car'):
            if (data.get('other_payment_plans') is None):
                return u'good'
            if (data['other_payment_plans'] == 'stores'):
                return u'good'
            if (data['other_payment_plans'] == 'bank'):
                if (data.get('job') is None):
                    return u'good'
                if (data['job'] != 'skilled'):
                    return u'bad'
                if (data['job'] == 'skilled'):
                    return u'good'
            if (data['other_payment_plans'] == 'none'):
                return u'good'
        if (data['purpose'] == 'furniture/equipment'):
            if (data.get('personal_status') is None):
                return u'good'
            if (data['personal_status'] == 'male div/sep'):
                return u'good'
            if (data['personal_status'] == 'male mar/wid'):
                if (data.get('employment') is None):
                    return u'good'
                if (data['employment'] != '1<=X<4'):
                    return u'bad'
                if (data['employment'] == '1<=X<4'):
                    return u'good'
            if (data['personal_status'] == 'female div/dep/mar'):
                if (data.get('job') is None):
                    return u'good'
                if (data['job'] == 'unskilled resident'):
                    if (data.get('savings_status') is None):
                        return u'good'
                    if (data['savings_status'] != '500<=X<1000'):
                        return u'good'
                    if (data['savings_status'] == '500<=X<1000'):
                        return u'bad'
                if (data['job'] == 'high qualif/self emp/mgmt'):
                    return u'bad'
                if (data['job'] == 'skilled'):
                    if (data.get('employment') is None):
                        return u'good'
                    if (data['employment'] == '4<=X<7'):
                        if (data.get('property_magnitude') is None):
                            return u'good'
                        if (data['property_magnitude'] != 'real estate'):
                            return u'good'
                        if (data['property_magnitude'] == 'real estate'):
                            return u'bad'
                    if (data['employment'] == '<1'):
                        if (data.get('property_magnitude') is None):
                            return u'bad'
                        if (data['property_magnitude'] == 'car'):
                            return u'bad'
                        if (data['property_magnitude'] == 'real estate'):
                            return u'good'
                        if (data['property_magnitude'] == 'life insurance'):
                            if (data.get('credit_amount') is None):
                                return u'bad'
                            if (data['credit_amount'] > 3456.0):
                                return u'bad'
                            if (data['credit_amount'] <= 3456.0):
                                return u'good'
                    if (data['employment'] == '1<=X<4'):
                        return u'good'
            if (data['personal_status'] == 'male single'):
                if (data.get('other_payment_plans') is None):
                    return u'good'
                if (data['other_payment_plans'] != 'bank'):
                    return u'good'
                if (data['other_payment_plans'] == 'bank'):
                    if (data.get('property_magnitude') is None):
                        return u'good'
                    if (data['property_magnitude'] != 'real estate'):
                        return u'good'
                    if (data['property_magnitude'] == 'real estate'):
                        return u'bad'
        if (data['purpose'] == 'new car'):
            if (data.get('other_payment_plans') is None):
                return u'good'
            if (data['other_payment_plans'] == 'stores'):
                if (data.get('credit_history') is None):
                    return u'good'
                if (data['credit_history'] != 'all paid'):
                    return u'bad'
                if (data['credit_history'] == 'all paid'):
                    return u'good'
            if (data['other_payment_plans'] == 'bank'):
                if (data.get('savings_status') is None):
                    return u'bad'
                if (data['savings_status'] == '>=1000'):
                    return u'good'
                if (data['savings_status'] == 'no known savings'):
                    if (data.get('credit_history') is None):
                        return u'bad'
                    if (data['credit_history'] != 'no credits/all paid'):
                        return u'good'
                    if (data['credit_history'] == 'no credits/all paid'):
                        return u'bad'
                if (data['savings_status'] == '500<=X<1000'):
                    if (data.get('credit_history') is None):
                        return u'bad'
                    if (data['credit_history'] != 'critical/other existing credit'):
                        return u'good'
                    if (data['credit_history'] == 'critical/other existing credit'):
                        return u'bad'
                if (data['savings_status'] == '<100'):
                    return u'bad'
                if (data['savings_status'] == '100<=X<500'):
                    return u'good'
            if (data['other_payment_plans'] == 'none'):
                if (data.get('age') is None):
                    return u'good'
                if (data['age'] > 30.5):
                    if (data['age'] > 66.0):
                        return u'bad'
                    if (data['age'] <= 66.0):
                        if (data.get('credit_history') is None):
                            return u'good'
                        if (data['credit_history'] != 'delayed previously'):
                            return u'good'
                        if (data['credit_history'] == 'delayed previously'):
                            if (data.get('job') is None):
                                return u'good'
                            if (data['job'] != 'skilled'):
                                return u'bad'
                            if (data['job'] == 'skilled'):
                                return u'good'
                if (data['age'] <= 30.5):
                    if (data.get('employment') is None):
                        return u'good'
                    if (data['employment'] == '4<=X<7'):
                        return u'good'
                    if (data['employment'] == '>=7'):
                        return u'bad'
                    if (data['employment'] == '<1'):
                        return u'good'
                    if (data['employment'] == '1<=X<4'):
                        if (data.get('personal_status') is None):
                            return u'good'
                        if (data['personal_status'] == 'male mar/wid'):
                            return u'good'
                        if (data['personal_status'] == 'female div/dep/mar'):
                            return u'bad'
                        if (data['personal_status'] == 'male single'):
                            if (data.get('residence_since') is None):
                                return u'good'
                            if (data['residence_since'] > 3.5):
                                return u'bad'
                            if (data['residence_since'] <= 3.5):
                                return u'good'
        if (data['purpose'] == 'radio/tv'):
            if (data.get('age') is None):
                return u'good'
            if (data['age'] > 23.0):
                if (data.get('credit_amount') is None):
                    return u'good'
                if (data['credit_amount'] > 3600.66666667):
                    if (data.get('savings_status') is None):
                        return u'good'
                    if (data['savings_status'] == '500<=X<1000'):
                        return u'good'
                    if (data['savings_status'] == '100<=X<500'):
                        return u'bad'
                    if (data['savings_status'] == '<100'):
                        if (data.get('credit_history') is None):
                            return u'good'
                        if (data['credit_history'] != 'delayed previously'):
                            return u'good'
                        if (data['credit_history'] == 'delayed previously'):
                            if (data.get('personal_status') is None):
                                return u'bad'
                            if (data['personal_status'] != 'male single'):
                                return u'good'
                            if (data['personal_status'] == 'male single'):
                                return u'bad'
                    if (data['savings_status'] == 'no known savings'):
                        if (data.get('employment') is None):
                            return u'good'
                        if (data['employment'] != '<1'):
                            return u'good'
                        if (data['employment'] == '<1'):
                            return u'bad'
                if (data['credit_amount'] <= 3600.66666667):
                    if (data.get('other_payment_plans') is None):
                        return u'good'
                    if (data['other_payment_plans'] != 'bank'):
                        return u'good'
                    if (data['other_payment_plans'] == 'bank'):
                        if (data.get('savings_status') is None):
                            return u'good'
                        if (data['savings_status'] == '100<=X<500'):
                            return u'good'
                        if (data['savings_status'] == 'no known savings'):
                            return u'bad'
                        if (data['savings_status'] == '500<=X<1000'):
                            if (data.get('job') is None):
                                return u'good'
                            if (data['job'] != 'skilled'):
                                return u'good'
                            if (data['job'] == 'skilled'):
                                return u'bad'
                        if (data['savings_status'] == '<100'):
                            return u'good'
            if (data['age'] <= 23.0):
                if (data.get('savings_status') is None):
                    return u'good'
                if (data['savings_status'] != '<100'):
                    return u'good'
                if (data['savings_status'] == '<100'):
                    if (data.get('credit_history') is None):
                        return u'bad'
                    if (data['credit_history'] != 'delayed previously'):
                        return u'bad'
                    if (data['credit_history'] == 'delayed previously'):
                        return u'good'
Close
