# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification and KNN with NHL data
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# Below you will practice KNN classification on a dataset of NHL statistics.
#
# You will be predicting the `Rank` of a team from predictor variables of your choice.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# web location:
web_csv = 'https://raw.githubusercontent.com/josephofiowa/GA-DSI/master/NHL_Data_GA.csv'
local_csv = '/Users/Mahendra/desktop/GA/hw/5.3.2_classification-knn_intro_to_classification-lab/datasets/NHL_Data_GA.csv'

# %% [markdown]
# ### 1. Load the NHL data

# %%
# A:
nhl=pd.read_csv('/Users/Mahendra/desktop/GA/hw/5.3.2_classification-knn_intro_to_classification-lab/datasets/NHL_Data_GA.csv')
nhl
# Out:
#               Team  PTS  Rank         TOI   GF   GA  GF60  GA60   GF%    SF  \
# 0     Washington10  121     1  2001:52:00  115   73  3.45  2.19  61.2  1112
# 1      Vancouver11  117     1  2056:14:00   94   72  2.74  2.10  56.6  1143
# 2       San Jose10  113     1  1929:54:00   90   68  2.80  2.11  57.0  1065
# 3        Chicago10  112     1  2020:23:00  104   83  3.09  2.46  55.6  1186
# 4      Vancouver12  111     1  2052:02:00   86   74  2.51  2.16  53.8  1078
# 5     NY Rangers12  109     1  2280:29:00   86   73  2.26  1.92  54.1  1096
# 6      St. Louis12  109     1  2256:55:00   87   65  2.31  1.73  57.2  1211
# 7     Pittsburgh12  108     1  1942:18:00   93   88  2.87  2.72  51.4  1135
# 8        Phoenix10  107     1  2082:24:00   75   67  2.16  1.93  52.8  1087
# 9     Washington11  107     1  2168:08:00   84   78  2.32  2.16  51.8  1152
# 10  Philadelphia11  106     1  1935:48:00  105   72  3.25  2.23  59.3  1104
# 11    Pittsburgh11  106     1  2036:20:00   87   75  2.56  2.21  53.7  1165
# 12      San Jose11  105     1  2134:14:00   85   71  2.39  2.00  54.5  1220
# 13       Detroit11  104     1  1984:21:00  105   84  3.17  2.54  55.6  1176
# 14     Nashville12  104     1  2061:44:00   90   82  2.62  2.39  52.3   972
# 15    New Jersey10  103     1  2095:56:00   84   71  2.40  2.03  54.2  1099
# 16     Vancouver10  103     1  1752:07:00   85   67  2.91  2.29  55.9   887
# 17        Boston11  103     1  2048:28:00   98   70  2.87  2.05  58.3  1163
# 18     Tampa Bay11  103     1  1899:25:00   91   71  2.87  2.24  56.2  1065
# 19  Philadelphia12  103     1  1908:03:00   90   82  2.83  2.58  52.3  1053
# 20       Detroit10  102     1  2064:18:00   79   90  2.30  2.62  46.8  1191
# 21        Boston12  102     1  2138:08:00   91   93  2.55  2.61  49.5  1181
# 22       Detroit12  102     1  2002:10:00   88   72  2.64  2.16  55.0  1091
# 23    New Jersey12  102     1  2245:54:00   67   82  1.79  2.19  45.0  1069
# 24   Los Angeles10  101     1  2146:05:00   78   68  2.18  1.90  53.4  1024
# 25    Pittsburgh10  101     1  2003:17:00  101   87  3.02  2.61  53.7  1177
# 26       Chicago12  101     1  2013:54:00   98   92  2.92  2.74  51.6  1143
# 27       Buffalo10  100     1  2011:04:00   75   86  2.24  2.57  46.6  1083
# 28     Nashville10  100     1  2293:29:00   93   84  2.43  2.20  52.5  1200
# 29       Anaheim11   99     2  2046:20:00   89   88  2.61  2.58  50.3   992
# ..             ...  ...   ...         ...  ...  ...   ...   ...   ...   ...
# 60     St. Louis11   87     3  2172:50:00   87   99  2.40  2.73  46.8  1137
# 79  ...   46.8  1829  2033  55.0  61.1  47.4   9.59  92.82  1024   954
# 80  ...   46.4  1859  2292  53.8  66.3  44.8   7.05  93.36  1004  1133
# 81  ...   51.3  2070  1954  63.7  60.1  51.4   7.55  91.57   991  1377
# 82  ...   48.8  1910  1956  55.7  57.0  49.4   6.58  91.17   978  1074
# 83  ...   48.5  1852  2054  53.7  59.5  47.4   7.23  91.55   988   942
# 84  ...   46.1  1881  2241  56.7  67.5  45.6   7.36  90.83   982   765
# 85  ...   49.3  2101  2151  58.5  59.9  49.4   6.78  91.99   988  1270
# 86  ...   51.1  1975  1905  58.2  56.2  50.9   8.00  91.18   992  1077
# 87  ...   49.6  2123  2059  59.8  58.0  50.8   7.17  92.27   994   902
# 88  ...   45.6  1765  2149  53.4  65.0  45.1   7.33  90.51   978   723
# 89  ...   43.8  1592  1993  50.4  63.1  44.4   6.96  91.18   981   754
#
# [90 rows x 28 columns]

# %% [markdown]
# ### 2. Perform any required data cleaning. Do some EDA.

# %%
# A:

# %% [markdown]
# ### 3. Set up the `Rank` variable as your target. How many classes are there?

# %%
# A:
nhl.columns
# Out:
# Index([u'Team', u'PTS', u'Rank', u'TOI', u'GF', u'GA', u'GF60', u'GA60',
#        u'GF%', u'SF', u'SA', u'SF60', u'SA60', u'SF%', u'FF', u'FA', u'FF60',
#        u'FA60', u'FF%', u'CF', u'CA', u'CF60', u'CA60', u'CF%', u'Sh%', u'Sv%',
#        u'PDO', u'PIM'],
#       dtype='object')

# %%
y=nhl['Rank']

# %% [markdown]
# ### 4. What is the baseline accuracy?

# %%
# A:
baseline=y.value_counts()/y.sum()
baseline
# Out:
# 3    0.170330
# 2    0.164835
# 1    0.159341
# Name: Rank, dtype: float64

# %% [markdown]
# ### 5. Choose 4 features to be your predictor variables and set up your design matrix.

# %%
# A:
x= nhl[['CF%', 'GF', 'Sh%', 'PDO']]

# %% [markdown]
# ### 6. Fit a `KNeighborsClassifier` with 1 neighbor using the target and predictors.

# %%
# A:
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# ### 7. Evaluate the accuracy of your model.
# - Is it better than baseline?
# - Is it legitimate?

# %%
# A:
y_pred_class=knn.predict(x)
from sklearn import metrics

print metrics.accuracy_score(y, y_pred_class)
# Out:
# 1.0

# %% [markdown]
# ### 8. Create a 50-50 train-test-split of your target and predictors. Refit the KNN and assess the accuracy.

# %%
# A:
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split




# STEP 1: split X and y into training and testing sets (using random_state for reproducibility)
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=99, test_size=0.5)

# STEP 2: train the model on the training set (using K=1)
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)

# STEP 3: test the model on the testing set, and check the accuracy
y_pred_class = knn.predict(X_test)
print metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.511111111111

# %% [markdown]
# ### 9. Evaluate the test accuracy of a KNN where K == number of rows in the training data.

# %%
# A:

# %% [markdown]
# ### 10. Fit the KNN at values of K from 1 to the number of rows in the training data.
# - Store the test accuracy in a list.
# - Plot the test accuracy vs. the number of neighbors.

# %%
# A:

# %% [markdown]
# ### 11. Fit KNN across different values of K and plot the mean cross-validated accuracy with 5 folds.

# %%
# A:

# %% [markdown]
# ### 12. Standardize the predictor matrix and cross-validate across the different K.
# - Plot the standardized mean cross-validated accuracy against the unstandardized. Which is better?
# - Why?

# %%
# A:
